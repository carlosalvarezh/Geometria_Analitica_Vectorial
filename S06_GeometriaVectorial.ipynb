# %% [markdown]
# <h1 align="center">Geometría Analítica y Vectorial</h1>
# <h1 align="center">Geometría Vectorial</h1>
# <h1 align="center">2024</h1>
# <h1 align="center">MEDELLÍN - COLOMBIA </h1>

# %% [markdown]
# ***
# |[![Outlook](https://img.shields.io/badge/Microsoft_Outlook-0078D4?style=plastic&logo=microsoft-outlook&logoColor=white)](mailto:calvarezh@udemedellin.edu.co)||[![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/carlosalvarezh/Geometria_Analitica_Vectorial/blob/main/S08_GeometriaVectorial.ipynb)
# |-:|:-|--:|
# |[![LinkedIn](https://img.shields.io/badge/linkedin-%230077B5.svg?style=plastic&logo=linkedin&logoColor=white)](https://www.linkedin.com/in/carlosalvarez5/)|[![@alvarezhenao](https://img.shields.io/twitter/url/https/twitter.com/alvarezhenao.svg?style=social&label=Follow%20%40alvarezhenao)](https://twitter.com/alvarezhenao)|[![@carlosalvarezh](https://img.shields.io/badge/github-%23121011.svg?style=plastic&logo=github&logoColor=white)](https://github.com/carlosalvarezh)|
#
# <table>
#  <tr align=left><td><img align=left src="https://github.com/carlosalvarezh/Curso_CEC_EAFIT/blob/main/images/CCLogoColorPop1.gif?raw=true" width="25">
#  <td>Text provided under a Creative Commons Attribution license, CC-BY. All code is made available under the FSF-approved MIT license.(c) Carlos Alberto Alvarez Henao</td>
# </table>
#
# ***

# %% [markdown]
# ## Vectores en el Plano

# %% [markdown]
# <p float="center">
#   <img src="https://github.com/carlosalvarezh/Geometria_Analitica_Vectorial/blob/main/Images/Vector00.PNG?raw=true" width="750" />
# </p>

# %% [markdown]
# ### Magnitudes escalares y vectoriales

# %% [markdown]
# Las magnitudes que emplearemos en este curso serán de dos tipos: [escalares](https://en.wikipedia.org/wiki/Scalar_(mathematics)) y [vectoriales](https://en.wikipedia.org/wiki/Euclidean_vector).
#
# Una *magnitud escalar* es aquella que queda completamente determinada con un número y sus correspondientes unidades, y una *magnitud vectorial* es aquella que, además de un valor numérico y sus unidades (módulo) debemos especificar su dirección y sentido.
#
# La elección de un escalar o un vector para representar una magnitud física depende de la naturaleza de la misma; si estamos describiendo la temperatura de una habitación, la densidad de un cuerpo, su masa... necesitaremos representarlas mediante un número. Por el contrario, cuando trabajemos con magnitudes como la fuerza, la velocidad, la aceleración, el campo eléctrico, etc., emplearemos vectores.
#
# Un vector en el plano (bidimensional o 2D) o  el espacio (tridimensional o 3D) está caracterizado por dos/tres números que se denominan componentes o coordenadas del vector.
#
# Las componentes de un vector serán en general diferentes dependiendo del sistema de coordenadas que utilicemos para expresarlas, pero siempre es posible relacionarlas de una manera sistemática.

# %% [markdown]
# ### Definición de Vector

# %% [markdown]
# Un **vector** es una entidad matemática que se define por dos características principales: **magnitud** (módulo o longitud) y **dirección**. Se representa gráficamente como un segmento de recta orientado, que tiene un punto de inicio (o cola) y un punto final (o cabeza).
#
# <p float="center">
#   <img src="https://github.com/carlosalvarezh/Geometria_Analitica_Vectorial/blob/main/Images/Vector01.PNG?raw=true" width="250" />
# </p>
#
# Matemáticamente, un vector en el espacio tridimensional se representa a menudo como una terna ordenada de números $\vec{a} = (x, y, z)$ o, de manera equivalente, como una combinación lineal de los vectores unitarios en las direcciones $X$, $Y$ y $Z$, $ \vec{a} = x\hat{i} + y\hat{j} + z\hat{k} $, donde $\hat{i}$, $\hat{j}$ y $\hat{k}$ son los vectores unitarios en las direcciones $X$, $Y$ y $Z$, respectivamente.
#
# <p float="center">
#   <img src="https://github.com/carlosalvarezh/Geometria_Analitica_Vectorial/blob/main/Images/Vector3D00.PNG?raw=true" width="250" />
# </p>
#
# En este curso emplearemos el sistema de coordenadas cartesianas. Como se indicó anteriormente, el sistema de coordenadas cartesianas está constituido por dos ejes (tres si trabajamos en tres dimensiones) perpendiculares entre sí que se cortan en un punto llamado origen.
#
# Las componentes cartesianas de un vector son las proyecciones de dicho vector sobre cada uno de los ejes.
#
# $$\vec{a} = (a_x, a_y, a_z)$$
#
# La magnitud (o longitud) de un vector $\vec{a} = (a_x, a_y, a_z)$ se calcula con la norma euclidiana:
#
# $$\| \vec{a} \| = \sqrt{a_x^2 + a_y^2 + a_z^2}$$
#
# Representa la "distancia" del vector desde el origen hasta su punto terminal (observe que se cumple el teorema de Pitágoras).
#
# ***Nota:*** Un vector se puede encontrar escrito de diversas maneras, dependiendo del gusto del editor En este curso indicaremos un vector con una flecha encima ( $\vec{a}$) o en negrita ($\textbf{a}$) (bold, en inglés). También, solemos expresarlo en sus componentes cartesianas.

# %% [markdown]
# ### Vector unitario

# %% [markdown]
# Un [**vector unitario**](https://en.wikipedia.org/wiki/Unit_vector) es un vector que tiene una magnitud (o longitud) de exactamente $1$ unidad, manteniendo una dirección específica. Estos vectores son particularmente útiles en matemáticas y física porque proporcionan una manera de representar puramente la dirección de un vector, sin preocuparse por su magnitud.

# %% [markdown]
# #### Características de un Vector Unitario

# %% [markdown]
# - ***Magnitud:*** La magnitud de un vector unitario es siempre $1$. Esto significa que su longitud en un gráfico es siempre de una unidad estándar, independientemente de su dirección.
#
# <p float="center">
#   <img src="https://github.com/carlosalvarezh/Geometria_Analitica_Vectorial/blob/main/Images/Vector06Unitario.gif?raw=true" width="200" />
# </p>
# <p>&nbsp;</p>
#
# 2. ***Dirección:*** La dirección de un vector unitario es su característica más importante. Indica la orientación del vector en el espacio, pero no su tamaño o longitud. La dirección se mantiene igual que la del vector original del cual se deriva el vector unitario.
# <p>&nbsp;</p>
#
# 3. ***Normalización:*** Para convertir un vector cualquiera en un vector unitario, se realiza un proceso llamado normalización. La normalización implica dividir cada componente del vector por la magnitud del vector original. Matemáticamente, si $\vec{a} = (x, y, z)$ es un vector, su vector unitario $\hat{a}$ se encuentra dividiendo $\vec{a}$ por su magnitud: $\hat{a} = \frac{\vec{a}}{\| \vec{a} \|}$.
# <p>&nbsp;</p>
#
# 4. ***Uso de Vectores Unitarios Estándar:*** En el sistema de coordenadas cartesianas $3D$, los vectores unitarios estándar son $\hat{i}$, $\hat{j}$ y $\hat{k}$, que representan las direcciones de los ejes $X$, $Y$ y $Z$, respectivamente. Cualquier vector en el plano puede expresarse como una combinación lineal de $\hat{i}$, $\hat{j}$ y $\hat{k}$.
# <p>&nbsp;</p>
#
# 5. **Aplicaciones:**
#    - Los vectores unitarios se utilizan para indicar direcciones en física, como la dirección de una fuerza, velocidad o aceleración.
#    - En ingeniería y gráficos por computadora, se utilizan para representar orientaciones y direcciones de movimiento o fuerza.

# %% [markdown]
# #### Ejemplos

# %% [markdown]
# ***1.*** Si tenemos un vector $\vec{a} = (3, 4)$, su magnitud es $\| \vec{a} \| = \sqrt{3^2 + 4^2} = 5$. El vector unitario $\hat{a}$ en la misma dirección que $\vec{a}$ se calcula como:
#
# $$ \hat{a} = \frac{\vec{a}}{\| \vec{a} \|} = \left( \frac{3}{5}, \frac{4}{5} \right) $$
#
# Este vector unitario $\hat{a}$ mantiene la dirección de $\vec{a}$ pero tiene una longitud de 1 unidad.
#
# ***
#
# ***2.*** Encontrar el punto medio 𝐶 del vector 𝐴𝐵 donde 𝐴 4,2, −6 , 𝐵 10,6,6 y encontrar el vector 𝐴𝐶
#
# $$ C\left(\frac{x_1 + x_2}{2}, \frac{y_1 + y_2}{2}, \frac{z_1 + z_2}{2}\right) $$
#
# Dado que $ A(4, 2, -6) $ y $ B(10, 6, 6) $, el punto medio $ C $ es:
#
# $$ C\left(\frac{4 + 10}{2}, \frac{2 + 6}{2}, \frac{-6 + 6}{2}\right) $$
# $$ = \left(\frac{14}{2}, \frac{8}{2}, \frac{0}{2}\right) $$
# $$ = (7, 4, 0) $$
#
# El vector $ \vec{AC} $ se encuentra restando las coordenadas de $ A $ de las de $ C $. Si $ A(x_1, y_1, z_1) $ y $ C(x_2, y_2, z_2) $, entonces $ \vec{AC} = (x_2 - x_1, y_2 - y_1, z_2 - z_1) $.
#
# Dado $ A(4, 2, -6) $ y $ C(7, 4, 0) $, tenemos:
#
# $$ \vec{AC} = (7 - 4, 4 - 2, 0 - (-6)) $$
# $$ = (3, 2, 6) $$
#
# Por lo tanto, el punto medio $ C $ es $ (7, 4, 0) $ y el vector $ \vec{AC} $ es $ (3, 2, 6) $.

# %% [markdown]
# ### Operaciones con vectores

# %% [markdown]
# Supongamos que tenemos dos vectores $\vec{u}$ y $\vec{v}$ en $3D$ (por facilidad en el dibujo, se hará en $2D$, pero es directamente extrapolable a $3D$):
#
# <p float="center">
#   <img src="https://github.com/carlosalvarezh/Geometria_Analitica_Vectorial/blob/main/Images/Vector07.gif?raw=true" width="350" />
# </p>
#
# Extrapolando a $3D$:
#
# $$\vec{u}=u_x\vec{i} + u_y\vec{j} + u_z\vec{k}$$
# $$\vec{v}=v_x\vec{i} + v_y\vec{j} + v_z\vec{k}$$

# %% [markdown]
# #### Suma de vectores

# %% [markdown]
# Se define el vector suma de ambos ($\vec{w}$) a otro vector cuyas componentes se calculan sumando las componentes de cada uno de ellos.
#
# <p float="center">
#   <img src="https://github.com/carlosalvarezh/Geometria_Analitica_Vectorial/blob/main/Images/Vector08.gif?raw=true" width="350" />
# </p>
#
# en $3D$:
#
# $$\vec{w}=\vec{u}+\vec{v}=w_x\vec{i} + w_y\vec{j} + w_z\vec{k}$$
#
# donde
#
# $$w_x=u_x + v_x$$
# $$w_y=u_y + v_y$$
# $$w_z=u_z + v_z$$
#
# De la figura se puede apreciar que gráficamente esto equivale a colocar un vector a continuación del otro y dibujar el vector desde el origen del primero al final del segundo.

# %% [markdown]
# #### Producto escalar

# %% [markdown]
# El producto escalar de dos vectores $u$ y $v$ que forman un ángulo $\phi$ se define como:
#
# <p float="center">
#   <img src="https://github.com/carlosalvarezh/Geometria_Analitica_Vectorial/blob/main/Images/Vector09.gif?raw=true" width="150" />
# </p>
#
# ***Caso $2D$:***
#
# Observe que el producto escalar de dos vectores no es un vector, es un número (un escalar). Además el producto escalar de dos vectores perpendiculares es nulo. Se deducen entonces los siguientes resultados:
#
# \begin{aligned}
# & \vec{i} \cdot \vec{i}=\vec{j} \cdot \vec{j} = 1 \\
# & \vec{i} \cdot \vec{j}=\vec{j} \cdot \vec{i} = 0
# \end{aligned}
#
# Si los vectores están expresados en componentes, en dos dimensiones y aplicando los resultados anteriores se obtiene que:
#
# $$\vec{u} \cdot \vec{v}=\left(u_x \vec{i}+u_y \vec{j}\right) \cdot\left(v_x \vec{i}+v_y \vec{j}\right)=u_x v_x+u_y v_y$$
#
# El producto escalar de dos vectores posee la propiedad [conmutativa](https://en.wikipedia.org/wiki/Commutative_property).
#
# ***Caso $3D$:***
#
# El producto escalar de dos vectores $\vec{u}$ y $\vec{v}$ que forman un ángulo $\phi$ en tres dimensiones se define de manera similar a como se hace en dos dimensiones. Sin embargo, en 3D se considera también la componente a lo largo del eje $Z$.
#
# Al igual que en el caso bidimensional, el producto escalar en tres dimensiones resulta en un número (un escalar), no en otro vector. También se mantiene la propiedad de que el producto escalar de dos vectores perpendiculares es cero. Esto lleva a los siguientes resultados:
#
# \begin{aligned}
# & \vec{i} \cdot \vec{i}=\vec{j} \cdot \vec{j}=\vec{k} \cdot \vec{k} = 1 \\
# & \vec{i} \cdot \vec{j}=\vec{j} \cdot \vec{k}=\vec{k} \cdot \vec{i} = 0
# \end{aligned}
#
# En tres dimensiones, si los vectores $\vec{u}$ y $\vec{v}$ están expresados en componentes como $\vec{u} = u_x \vec{i} + u_y \vec{j} + u_z \vec{k}$ y $\vec{v} = v_x \vec{i} + v_y \vec{j} + v_z \vec{k}$, entonces el producto escalar se obtiene como:
#
# $$\vec{u} \cdot \vec{v} = \left(u_x \vec{i} + u_y \vec{j} + u_z \vec{k}\right) \cdot \left(v_x \vec{i} + v_y \vec{j} + v_z \vec{k}\right) = u_x v_x + u_y v_y + u_z v_z$$
#
#
# **Propiedad del Ángulo en el Producto Escalar**
#
# El producto escalar entre dos vectores no solo proporciona información sobre su magnitud, sino que también puede usarse para determinar el ángulo $\phi$ entre ellos. Esta propiedad es válida tanto en dos como en tres dimensiones.
#
# Si se tienen dos vectores $\vec{u}$ y $\vec{v}$, el producto escalar entre ellos se define como:
#
# $$\vec{u} \cdot \vec{v} = |\vec{u}| |\vec{v}| \cos(\phi)$$
#
# Donde $|\vec{u}|$ y $|\vec{v}|$ son las magnitudes (o normas) de los vectores $\vec{u}$ y $\vec{v}$ respectivamente, y $\phi$ es el ángulo entre los dos vectores. Esta ecuación se puede reorganizar para hallar el ángulo $\phi$:
#
# $$\phi = \cos^{-1}\left(\frac{\vec{u} \cdot \vec{v}}{|\vec{u}| |\vec{v}|}\right)$$
#
# Este cálculo del ángulo es especialmente útil en diversas aplicaciones como:
#
# 1. **Determinar la Ortogonalidad**: Si el producto escalar es $0$, entonces $\phi = 90^{\circ}$, lo que indica que los vectores son ortogonales (perpendiculares entre sí).
#
# 2. **Análisis de Direcciones**: Puede usarse para verificar si dos vectores están en la misma dirección (ángulo de $0^{\circ}$) o en direcciones opuestas (ángulo de $180^{\circ}$).
#
# ***Nota:*** al producto escalar entre dos vectores también se le conoce como producto punto.

# %% [markdown]
# ##### Ejemplos producto escalar

# %% [markdown]
# ***Ejemplo 1.*** obtener el ángulo 𝜃 entre las líneas $𝑙_1 = 3𝑥 + 4𝑦 − 8$ y $𝑙_2 = 4𝑥 − 3𝑦 + 9 = 0$
#
# Vamos a resolver este ejemplo de varias formas diferentes:
#
# - ***Tangente del Ángulo entre las rectas (Usando Pendientes)***
#
# En el primer método, calculamos el ángulo usando la fórmula de la tangente del ángulo entre dos líneas, que se basa en sus pendientes:
#
# $$ \tan(\theta) = \left| \frac{m_1 - m_2}{1 + m_1 m_2} \right| = \left| \frac{\frac{-3}{4} - \frac{4}{3}}{1 + \frac{-3}{4}\frac{4}{3}} \right| =  \left| \frac{\frac{-25}{12}}{1 - 1} \right|= \left| \frac{-25}{0} \right|$$
#
# Al denominador ser cero, tenemos una indeterminación, es decir $\tan(\theta) \rightarrow \infty$. Esto quiere decir que se tiene una asíntota vertical, por lo que se concluye que ambas rectas son perpendiculares: $l_1 \perp l_2$
#
# - ***Perpendicularidad entre rectas (concepto)***
#
# Del enunciado se observa que las pendientes de las rectas $l_1$ y $l_2$, son respectivamente, $m_1=-3/4$ y $m_2=4/3$, y recordando del capítulo de *la recta* que si se tiene qué  $m_1 \times m_2 = -1$, entonces ambas rectas son perpediculares entre sí. Reemplazando los valores de las pendientes $m_1 \times m_2 = -3/4 \times 4/3 = -1$. Se comprueba, nuevamente, que $l_1 \perp l_2$.
#
#
# - ***Producto Escalar (Usando Vectores Direccionales)***
#
# Por último, usamos el producto escalar de los vectores direccionales de las líneas:
#
# $$ \cos(\theta) = \frac{\vec{v_1} \cdot \vec{v_2}}{|\vec{v_1}| |\vec{v_2}|} $$
#
# Con $\vec{v_1} = (3, 4)$ y $\vec{v_2} = (4, -3)$, calculemos el producto escalar entre ellos:
#
# $$\vec{v_1} \cdot \vec{v_2} = 3 \times 4 + 4 \times (-3) = 12 - 12 = 0$$
#
# Observemos que el producto punto es cero, por lo que quiere decir que ambas rectas son perpendiculares entre sí, confirmando los resultados previamente encontrados por los otros métodos.
#
# ***Ejemplo 2.*** Empleando el concepto del producto punto decir si los triángulos cuyos vértices se presentan son equiláteros, rectángulos o ninguno. $𝑃1(0,0,0)$; $𝑃2(2,2,1)$ y $𝑃3(2,−4,4)$.
#
# - ***Paso 1: Calculo  de las Longitudes de los Lados***
#
# Calculamos las longitudes de los lados del triángulo formado por los puntos $ P1(0,0,0) $, $ P2(2,2,1) $, y $ P3(2,-4,4) $ usando la fórmula de la distancia en el espacio tridimensional:
#
# $$ d(P1, P2) = \sqrt{(2-0)^2 + (2-0)^2 + (1-0)^2} = \sqrt{4+4+1}=\sqrt{9}=3$$
# $$ d(P2, P3) = \sqrt{(2-2)^2 + (-4-2)^2 + (4-1)^2} = \sqrt{0+36+9}=\sqrt{45}$$
# $$ d(P1, P3) = \sqrt{(2-0)^2 + (-4-0)^2 + (4-0)^2} = \sqrt{4+16+16} = \sqrt{36} = 6$$
#
# - ***Paso 2: Comprobar si es un Triángulo Equilátero***
#
# Comprobamos si todas las longitudes calculadas en el Paso 1 son iguales. Se observa que $d(P1, P2) \neq d(P2, P3) \neq d(P1, P3)$, por lo que se concluye que no es un triángulo equilátero.
#
# - ***Paso 3: Comprobar si es un Triángulo Rectángulo***
#
# Para determinar si el triángulo es rectángulo, calculamos el producto punto entre los vectores que forman los lados del triángulo. Los vectores son:
#
# $$ \vec{P1P2} = (2-0, 2-0, 1-0) = (2, 2, 1) $$
# $$ \vec{P2P3} = (2-2, -4-2, 4-1) = (0, -6, 3) $$
# $$ \vec{P1P3} = (2-0, -4-0, 4-0) = (2, -4, 4) $$
#
# El producto punto entre los vectores se calcula como:
#
# $$ \vec{P1P2} \cdot \vec{P2P3} = (2 \times 0) + (2 \times -6) + (1 \times 3) = 0-12+3 = 9 $$
# $$ \vec{P2P3} \cdot \vec{P1P3} = (0 \times 2) + (-6 \times -4) + (3 \times 4)= 0+24+12=36 $$
# $$ \vec{P1P2} \cdot \vec{P1P3} = (2 \times 2) + (2 \times -4) + (1 \times 4) = 4-8+4=0$$
#
# Si alguno de estos productos es cero, el triángulo es rectángulo. Vamos a calcular estas cantidades.
#
# - ***Conclusión***
#
# Las longitudes de los lados son $ 3 $, $ \sqrt{45} $ y $ 6 $, por lo que el triángulo **no es equilátero**. Además, uno de los productos punto es cero, específicamente el producto punto entre $ \vec{P1P2} $ y $ \vec{P1P3} $, lo que indica que el triángulo es **rectángulo** en $ P2 $. Por lo tanto, el triángulo formado por los puntos $ P1 $, $ P2 $ y $ P3 $ es un triángulo rectángulo pero no equilátero.

# %% [markdown]
# #### Producto de un vector por un escalar

# %% [markdown]
# <p float="center">
#   <img src="https://github.com/carlosalvarezh/Geometria_Analitica_Vectorial/blob/main/Images/Vector11.PNG?raw=true" width="150" />
# </p>
#
# En tres dimensiones, un vector $\vec{v}$ se puede expresar en términos de sus componentes a lo largo de los ejes $x$, $y$, $z$, es decir, $\vec{v} = v_x \vec{i} + v_y \vec{j} + v_z \vec{k}$. El producto de este vector por un escalar $\alpha$ resulta en un nuevo vector $\vec{w}$ cuyas componentes son escaladas por $\alpha$. Matemáticamente, se expresa como:
#
# $$\alpha \vec{v} = \alpha (v_x \vec{i} + v_y \vec{j} + v_z \vec{k}) = (\alpha v_x) \vec{i} + (\alpha v_y) \vec{j} + (\alpha v_z) \vec{k} = w_x \vec{i} + w_y \vec{j} + w_z \vec{k}$$
#
# Donde $\vec{w} = \alpha \vec{v}$ es el vector resultante de la multiplicación.
#
# Este proceso se puede visualizar como un estiramiento o una compresión del vector original en todas las direcciones, manteniendo su dirección pero cambiando su magnitud. Si el escalar es mayor que $1$, el vector se alarga (estira); si está entre $0$ y $1$, se acorta (comprime); y si es negativo, además de cambiar su longitud, el vector cambia de dirección (se invierte).
#
# Es importante destacar que:
#
# 1. **Mantenimiento de la Dirección**: La dirección del vector original se mantiene, a menos que el escalar sea negativo, en cuyo caso el vector se invierte.
#
# 2. **Cambio en la Magnitud**: La magnitud del vector cambia en función del valor absoluto del escalar.
#
# 3. **Caso Especial de Cero**: Si el escalar es cero, el vector resultante es el vector nulo, independientemente del vector original.
#
# En aplicaciones prácticas, el producto de un vector por un escalar es útil en física (por ejemplo, para describir el escalado de velocidades o fuerzas).

# %% [markdown]
# #### Producto vectorial

# %% [markdown]
# El producto vectorial de dos vectores que forman un ángulo $\phi$ es otro vector, de dirección perpendicular al plano formado por los dos vectores, sentido el que da la regla de la mano derecha y módulo el que se especifica a continuación:
#
# <p float="center">
#   <img src="https://github.com/carlosalvarezh/Geometria_Analitica_Vectorial/blob/main/Images/Vector10.gif?raw=true" width="150" />
# </p>
#
# $$w = uv\sin(\phi)$$
#
# El producto vectorial **no posee la propiedad conmutativa**, ya que se cumple que:
#
# $$\vec{u} \times \vec{v} = -\vec{v} \times \vec{u}$$
#
# Además, se cumple que el producto vectorial de dos vectores paralelos es nulo. Se obtienen entonces las siguientes relaciones ($2D$):
#
# \begin{aligned}
# & \vec{i} \times \vec{i}=\vec{j} \times \vec{j}=\vec{k} \times \vec{k}=0 \\
# & \vec{i} \times \vec{j}=\vec{k} \quad \vec{j} \times \vec{k}=\vec{i} \quad \vec{k} \times i=\vec{j}
# \end{aligned}
#
# Si los vectores vienen expresados en componentes el producto vectorial se calcula desarrollando el determinante:
#
# $$
# \vec{u} \times \vec{v}=\left|\begin{array}{ccc}
# \vec{i} & \vec{j} & \vec{k} \\
# u_x & u_y & u_z \\
# v_x & v_y & v_z
# \end{array}\right|
# $$
#
# **Producto Vectorial en Tres Dimensiones**
#
# En tres dimensiones, el producto vectorial de dos vectores $\vec{u}$ y $\vec{v}$, que forman un ángulo $\phi$, es un vector $\vec{w}$ que tiene las siguientes características:
#
# 1. **Dirección**: Perpendicular al plano formado por $\vec{u}$ y $\vec{v}$.
# 2. **Sentido**: Determinado por la regla de la mano derecha: si los dedos de la mano derecha apuntan de $\vec{u}$ a $\vec{v}$, el pulgar apunta en la dirección de $\vec{w}$.
# 3. **Módulo**: El módulo de $\vec{w}$ es igual a $uv\sin(\phi)$, donde $u$ y $v$ son los módulos de $\vec{u}$ y $\vec{v}$ respectivamente.
#
# El producto vectorial en $3D$, al igual que en otras dimensiones, **no es conmutativo**. Se cumple que:
#
# $$\vec{u} \times \vec{v} = -\vec{v} \times \vec{u}$$
#
# Esto significa que el cambio en el orden de los vectores invierte la dirección del vector resultante.
#
# Otra propiedad importante es que el producto vectorial de dos vectores paralelos es un vector nulo. En el caso de los vectores unitarios en el espacio tridimensional, se tienen las siguientes relaciones:
#
# \begin{aligned}
# & \vec{i} \times \vec{i}=\vec{j} \times \vec{j}=\vec{k} \times \vec{k}=0 \\
# & \vec{i} \times \vec{j}=\vec{k}, \quad \vec{j} \times \vec{k}=\vec{i}, \quad \vec{k} \times \vec{i}=\vec{j} \\
# & \vec{j} \times \vec{i}=-\vec{k}, \quad \vec{k} \times \vec{j}=-\vec{i}, \quad \vec{i} \times \vec{k}=-\vec{j}
# \end{aligned}
#
# Para calcular el producto vectorial cuando los vectores están expresados en componentes, se utiliza el determinante de una matriz $3\times3$ formada por los vectores unitarios $\vec{i}, \vec{j}, \vec{k}$ en la primera fila, y las componentes de $\vec{u}$ y $\vec{v}$ en la segunda y tercera fila respectivamente:
#
# $$
# \vec{u} \times \vec{v}=\left|\begin{array}{ccc}
# \vec{i} & \vec{j} & \vec{k} \\
# u_x & u_y & u_z \\
# v_x & v_y & v_z
# \end{array}\right|
# $$
#
# El resultado de este determinante es el vector $\vec{w}$, que es perpendicular a ambos $\vec{u}$ y $\vec{v}$ y cuyo módulo es el área del paralelogramo que forman estos dos vectores.
#
#
# Otras propiedades del producto vectorial es:
#
# $$|\vec{u} \times \vec{v}1=|\vec{u}|\dot|\vec{v}|\sin(\theta)$$
#
# y
#
# $|\vec{u} \times \vec{v}|=\vec{0}$ cuando $\vec{u}$ y $\vec{v}$ son paralelos, o alguno de los dos vectores es cero.
#
# ***Nota:*** La fórmula general para calcular el determinante de una matriz de $3 \times 3$ en tres dimensiones se basa en la [regla de Sarrus](https://en.wikipedia.org/wiki/Rule_of_Sarrus). Consideremos una matriz de 3x3 con elementos:
#
# $$ A = \begin{bmatrix} a & b & c \\ d & e & f \\ g & h & i \end{bmatrix} $$
#
# El determinante de $ A $, denotado como $ \text{det}(A) $ o $ |A| $, se calcula de la siguiente manera:
#
# $$ \text{det}(A) = aei + bfg + cdh - ceg - bdi - afh $$
#
# Esta fórmula se obtiene sumando los productos de las diagonales de la matriz que van de izquierda a derecha y restando los productos de las diagonales que van de derecha a izquierda.
#
# ***Ejemplo cálculo del determinante en 3D por la regla de sarrus:***
#
# Para ilustrar el proceso con un ejemplo, si tomamos la matriz:
#
# $$ A = \begin{bmatrix} 1 & 2 & 3 \\ 4 & 5 & 6 \\ 7 & 8 & 9 \end{bmatrix} $$
#
# Su determinante se calcula como:
#
# $$ \text{det}(A) = 1 \cdot 5 \cdot 9 + 2 \cdot 6 \cdot 7 + 3 \cdot 4 \cdot 8 - 3 \cdot 5 \cdot 7 - 2 \cdot 4 \cdot 9 - 1 \cdot 6 \cdot 8 $$

# %% [markdown]
# #### Triple producto vectorial

# %% [markdown]
# El triple producto vectorial es una operación vectorial que se aplica sobre tres vectores en el espacio tridimensional. Esta operación se define como el producto vectorial entre un vector y el producto vectorial de otros dos vectores.
#
# <p float="center">
#   <img src="https://github.com/carlosalvarezh/Geometria_Analitica_Vectorial/blob/main/Images/Vector12.PNG?raw=true" width="150" />
# </p>
#
# $$ \vec{u} \times (\vec{v} \times \vec{w}) $$
#
# donde $\vec{u}$, $\vec{v}$, y $\vec{w}$ son vectores en el espacio tridimensional.
#
# ***Interpretación Geométrica***
#
# El triple producto vectorial $\vec{u} \times (\vec{v} \times \vec{w})$ produce un vector que es perpendicular al vector $\vec{u}$ y que está en el plano formado por $\vec{v}$ y $\vec{w}$.
#
# ***Propiedad Matemática***
#
# Una propiedad importante del triple producto vectorial es que puede reescribirse utilizando una combinación lineal de los otros dos vectores. Esto se conoce como la *fórmula del desarrollo del triple producto vectorial* y se expresa como:
#
# $$ \vec{u} \times (\vec{v} \times \vec{w}) = (\vec{u} \cdot \vec{c})\vec{v} - (\vec{u} \cdot \vec{v})\vec{w} $$
#
# Esta fórmula muestra que el resultado del triple producto vectorial es una combinación de los vectores $\vec{v}$ y $\vec{w}$, ponderada por los productos escalares de $\vec{u}$ con $\vec{w}$ y $\vec{v}$, respectivamente.
#
# ***Procedimiento de cálculo***
#
# Consideremos los vectores $\vec{u} = (u_1, u_2, u_3)$, $\vec{v} = (v_1, v_2, v_3)$, y $\vec{w} = (w_1, w_2, w_3)$. El triple producto vectorial se calcula como sigue:
#
# 1. Primero calculamos el producto vectorial de $\vec{v} \times \vec{w}$.
# 2. Luego, el resultado se usa para calcular el producto vectorial con $\vec{u}$.
#
# Este proceso puede requerir el uso de la determinante para el cálculo del producto vectorial y luego la aplicación de la fórmula del desarrollo del triple producto vectorial.
#
# ***Aplicaciones***
#
# El triple producto vectorial es útil en física y ingeniería, especialmente en situaciones que implican rotaciones y momentos angulares. Por ejemplo, en la dinámica de cuerpos rígidos, puede usarse para encontrar direcciones perpendiculares a ciertos planos o para calcular componentes de fuerzas en direcciones específicas.

# %% [markdown]
# ##### Ejemplos Producto Vectorial

# %% [markdown]
# - ***Ejemplo 1. Determinación del Área de un Paralelogramo:*** Dados dos vectores en el plano, $ \vec{a} = (3, 2) $ y $ \vec{b} = (1, 4) $, el área del paralelogramo formado por estos vectores se obtiene calculando el módulo del producto vectorial $ \vec{a} \times \vec{b} $. Este cálculo implica encontrar un vecftor perpendicular a afmbos y luego calcular su magnitud.
#
#   En dos dimensiones, el "producto vectorial" de dos vectores $ \vec{a} $ y $ \vec{b} $ puede interpretarse como el determinante de una matriz formada por estos vectores, que nos da un valor escalar representando el área del paralelogramo formado por los vectores. En otras palabras, la magnitud del producto vectorial en $2D$ es igual al área del paralelogramo.
#
#   La fórmula para el área $ A $ del paralelogramo es:$ A = |\vec{a} \times \vec{b}| $
#
#   El producto vectorial $ \vec{a} \times \vec{b} $ en 2D es: $ \vec{a} \times \vec{b} = a_x b_y - a_y b_x $
#
#   Reemplazando los valores de $ \vec{a} $ y $ \vec{b} $ obtenemos: $ \vec{a} \times \vec{b} = 3 \times 4 - 2 \times 1 = 12 - 2 = 10$
#
#   Entonces, el área $ A $ del paralelogramo formado por $ \vec{a} $ y $ \vec{b} $ es $ |10| $, es decir, 10 unidades cuadradas.
# <p>&nbsp;</p>
#
# - ***Ejemplo 2. Determinación de la Orientación Relativa (Regla de la Mano Derecha):*** Dados dos vectores $ \vec{u} = (4, 5) $ y $ \vec{v} = (-2, 3) $, el signo del producto vectorial $ \vec{u} \times \vec{v} $ indica si $ \vec{v} $ está a la izquierda o a la derecha de $ \vec{u} $ cuando se colocan con el mismo punto inicial. Esto se usa para determinar la orientación relativa de los vectores.
#
#   En dos dimensiones, el producto vectorial puede interpretarse como el determinante de una matriz formada por los dos vectores. Este determinante nos dará un valor escalar que indica la orientación relativa de los vectores.
#
#   La fórmula para el producto vectorial $ \vec{u} \times \vec{v} $ es:
# $$ \vec{u} \times \vec{v} = u_x v_y - u_y v_x $$
#
#   Sustituimos los valores de $ \vec{u} $ y $ \vec{v} $ en la fórmula:
# $$ \vec{u} \times \vec{v} = 4 \times 3 - 5 \times (-2) $$
# $$ \vec{u} \times \vec{v} = 12 + 10 $$
# $$ \vec{u} \times \vec{v} = 22 $$
#
# - ***Interpretación del Resultado:*** Dado que el resultado es un número positivo, esto indica que el vector $ \vec{v} $ está a la izquierda de $ \vec{u} $ cuando ambos vectores se originan en el mismo punto. Esto se debe a que un producto vectorial positivo en $2D$ implica que el segundo vector (en este caso $ \vec{v} $) debe ser girado en el sentido de las agujas del reloj para superponerse con el primer vector (en este caso $ \vec{u} $), según la *Regla de la Mano Derecha*.
# <p>&nbsp;</p>
#
# - ***Ejemplo 3. Cálculo del Momento de una Fuerza:*** En mecánica, el momento de una fuerza respecto a un punto se calcula mediante el producto vectorial. Si una fuerza $ \vec{F} = (5, 0, 0) $ N actúa en un punto que está a un vector posición $ \vec{r} = (0, 4, 0) $ m del punto de pivote, el momento es $ \vec{M} = \vec{r} \times \vec{F} $.
#
# En física, el momento de una fuerza respecto a un punto (también conocido como torque) se calcula mediante el producto vectorial del vector posición $ \vec{r} $ y la fuerza $ \vec{F} $. El momento $ \vec{M} $ es entonces:
#
# $$ \vec{M} = \vec{r} \times \vec{F} $$
#
# El producto vectorial en 3D se calcula como sigue:
#
# $$ \vec{M} = \begin{vmatrix}
# \vec{i} & \vec{j} & \vec{k} \\
# r_x & r_y & r_z \\
# F_x & F_y & F_z \\
# \end{vmatrix} $$
#
# Sustituimos los valores de $ \vec{r} $ y $ \vec{F} $ en el determinante:
#
# $$ \vec{M} = \begin{vmatrix}
# \vec{i} & \vec{j} & \vec{k} \\
# 0 & 4 & 0 \\
# 5 & 0 & 0 \\
# \end{vmatrix} $$
#
# El cálculo del determinante nos da:
#
# $$ \vec{M} = \vec{i} \cdot (4 \cdot 0 - 0 \cdot 0) - \vec{j} \cdot (0 \cdot 0 - 0 \cdot 5) + \vec{k} \cdot (0 \cdot 0 - 4 \cdot 5) $$
# $$ \vec{M} = \vec{i} \cdot 0 + \vec{j} \cdot 0 - 20 \vec{k} $$
# $$ \vec{M} = -20 \vec{k} $$
#
# Por lo tanto, el momento de la fuerza $ \vec{F} $ respecto al punto de pivote dado por $ \vec{r} $ es $ -20 \vec{k} $ newton-metros, lo que indica un momento de 20 newton-metros en la dirección negativa del eje $ z $.
#
# <p>&nbsp;</p>
#
# - ***Ejemplo 4. Rotación en Espacio Tridimensional:*** Al diseñar un sistema de navegación para una aeronave, el cambio de orientación puede modelarse utilizando el producto vectorial. Si un avión se desplaza a lo largo de un vector $ \vec{v} = (0, 0, 1) $ y gira en torno a un eje representado por $ \vec{e} = (0, 1, 0) $, el vector de rotación puede determinarse mediante $ \vec{e} \times \vec{v} $.
#
#   El producto vectorial $ \vec{e} \times \vec{v} $ en 3D se calcula utilizando la regla de la mano derecha y la definición matemática del producto cruz. La fórmula es:
#
# $$ \vec{e} \times \vec{v} = \begin{vmatrix}
# \vec{i} & \vec{j} & \vec{k} \\
# e_x & e_y & e_z \\
# v_x & v_y & v_z \\
# \end{vmatrix} $$
#
# Sustituimos los valores de $ \vec{e} $ y $ \vec{v} $ en el determinante:
#
# $$ \vec{e} \times \vec{v} = \begin{vmatrix}
# \vec{i} & \vec{j} & \vec{k} \\
# 0 & 1 & 0 \\
# 0 & 0 & 1 \\
# \end{vmatrix} $$
#
# El cálculo del determinante nos da:
#
# $$ \vec{e} \times \vec{v} = \vec{i} \cdot (1 \cdot 1 - 0 \cdot 0) - \vec{j} \cdot (0 \cdot 1 - 0 \cdot 0) + \vec{k} \cdot (0 \cdot 0 - 1 \cdot 0) $$
# $$ \vec{e} \times \vec{v} = \vec{i} \cdot 1 - \vec{j} \cdot 0 + \vec{k} \cdot 0 $$
# $$ \vec{e} \times \vec{v} = \vec{i} $$
#
# Por lo tanto, el vector de rotación $ \vec{e} \times \vec{v} $ es $ \vec{i} $, indicando que la rotación resultante del avión ocurre en la dirección del eje $ x $ positivo. Esto significa que el avión gira hacia la derecha respecto a su dirección actual de movimiento hacia adelante.

# %% [markdown]
# #### Suma de Vectores por el Método Gráfico - Método del Paralelogramo

# %% [markdown]
# El método del paralelogramo es una técnica gráfica utilizada para sumar dos vectores. Es especialmente útil en física e ingeniería para visualizar y determinar la suma de dos vectores en términos de magnitud y dirección. Este método se basa en la geometría del paralelogramo para representar gráficamente la suma de vectores.
#
# ***Pasos del Método del Paralelogramo***
#
# <p float="center">
#   <img src="https://github.com/carlosalvarezh/Geometria_Analitica_Vectorial/blob/main/Images/SumaVectores00.PNG?raw=true" width="350" />
# </p>
#
# Para sumar dos vectores $\vec{u}$ y $\vec{v}$ utilizando el método del paralelogramo, se siguen los siguientes pasos:
#
# 1. **Representación Gráfica de los Vectores**: Dibuje los vectores $\vec{u}$ y $\vec{v}$ con una escala y orientación adecuadas, originados desde el mismo punto.
#
# 2. **Construcción del Paralelogramo**: A partir de la punta de cada vector, dibuje líneas paralelas al otro vector, formando un paralelogramo.
#
# 3. **Dibujar la Diagonal**: La suma de los vectores $\vec{u}$ y $\vec{v}$, denotada como $\vec{R}$ (vector resultante), se obtiene trazando una línea desde el punto de origen común hasta la esquina opuesta del paralelogramo.
#
# 4. **Medición del Vector Resultante**: El vector resultante $\vec{R}$ se puede medir y calcular en términos de su magnitud y dirección utilizando reglas y transportadores, respectivamente, según la escala utilizada.
#
# ***Interpretación Geométrica***
#
# Geometricamente, el método del paralelogramo muestra que la suma de dos vectores no es simplemente una suma de sus magnitudes, sino una combinación de sus magnitudes y direcciones. El vector resultante representa tanto la dirección como la magnitud total del efecto combinado de los dos vectores.
#
# ***Ejemplo Ilustrativo***
#
# Supongamos que queremos sumar dos vectores: $\vec{u} = 5 \, \text{unidades}$ en dirección este y $\vec{v} = 3 \, \text{unidades}$ en dirección norte. Dibujamos $\vec{u}$ y $\vec{v}$ con sus respectivas magnitudes y direcciones. Luego, trazamos líneas paralelas a cada uno de ellos para formar un paralelogramo y dibujamos la diagonal. Esta diagonal representa el vector resultante $\vec{R}$ tanto en magnitud como en dirección.
#
# ***Aplicaciones Prácticas***
#
# El método del paralelogramo se utiliza en física para la suma de diferentes tipos de vectores como fuerzas, velocidades y desplazamientos. Permite a los ingenieros y científicos visualizar cómo dos fuerzas o movimientos interactúan y resultan en un efecto combinado.

# %% [markdown]
# #### Ley de cosenos

# %% [markdown]
# Cuando sumamos dos vectores $\vec{u}$ y $\vec{v}$ utilizando el método del paralelogramo, a menudo nos interesa no solo la dirección del vector resultante, sino también su magnitud. Si conocemos las magnitudes de $\vec{u}$ y $\vec{v}$, así como el ángulo $\theta$ entre ellos, podemos aplicar la Ley de los Cosenos para encontrar la magnitud del vector resultante $\vec{w}$ (la diagonal del paralelogramo)
#
# $$|\vec{w}|=\sqrt{|\vec{u}|^2 + |\vec{v}|^2 - 2|\vec{u}||\vec{v}|\cos(\theta)}$$
#
#
# ***Interpretación Geométrica***
#
# En el contexto del paralelogramo, $\theta$ es el ángulo menor entre los vectores $\vec{u}$ y $\vec{v}$. La fórmula toma en cuenta este ángulo para calcular correctamente la magnitud de $\vec{w}$. Si los vectores son perpendiculares (ángulo de 90 grados), el término $-2|\vec{u}||\vec{v}|\cos(\theta)$ se anula, y la fórmula se reduce al teorema de Pitágoras.
#
# ***Ejemplo Práctico***
#
# Si tenemos dos vectores, $\vec{u}$ y $\vec{v}$, con magnitudes de 5 y 3 unidades, respectivamente, y forman un ángulo de 60°, entonces la magnitud de $\vec{w}$ sería:
#
# $$|\vec{w}|=\sqrt{5^2 + 3^2 - 2 \times 5 \times 3 \times \cos(60^\circ)}$$
#
# Este cálculo nos da la longitud del vector resultante.

# %% [markdown]
# #### Descomposicion de un vector

# %% [markdown]
# ***Descomposición de un Vector en 2D***
#
# En dos dimensiones, un vector se puede descomponer en componentes a lo largo de los ejes $x$ e $y$. Estas componentes se pueden encontrar utilizando trigonometría, especialmente si se conoce el ángulo del vector con respecto a uno de los ejes.
#
# 1. **Representación del Vector**: Sea $\vec{V}$ un vector en $2D$, con un ángulo $\theta$ desde el eje $x$ positivo.
#
# 2. **Componentes del Vector**: Las componentes del vector $\vec{V} = (V_x, V_y)$ se pueden calcular como sigue:
#    - $ V_x = |\vec{V}| \cos(\theta) $
#    - $ V_y = |\vec{V}| \sin(\theta) $
#
#    donde $|\vec{V}|$ es la magnitud del vector.
#
# Con lo anterior, para un vector $\vec{W}$ dado, $\vec{W}=w_x\vec{i}+w_y\vec{j}$, tenemos:
#
# $$\vec{W}=|\vec{W}|\cdot \cos(\theta)\vec{i}+|\vec{W}|\cdot \sin(\theta)\vec{j}$$
#
# donde $\theta$ es el ángulo que forma $|\vec{W}|$ con la horizontal.
#
#
# ***Descomposición de un Vector en 3D***
#
# En tres dimensiones, un vector se descompone en componentes a lo largo de los ejes $x$, $y$, y $z$. Este proceso es una extensión del método en $2D$ e involucra considerar un ángulo adicional.
#
# 1. **Representación del Vector**: Sea $\vec{W}$ un vector en $3D$.
#
# 2. **Componentes del Vector**: Las componentes de $\vec{W} = (W_x, W_y, W_z)$ se pueden determinar a partir de la proyección del vector en los tres ejes. Si conocemos los ángulos que $\vec{W}$ forma con los ejes $x$, $y$, y $z$, las componentes se pueden calcular como:
#    - $ W_x = |\vec{W}| \cos(\theta_x) $
#    - $ W_y = |\vec{W}| \cos(\theta_y) $
#    - $ W_z = |\vec{W}| \cos(\theta_z) $
#
#    Aquí, $\theta_x$, $\theta_y$, y $\theta_z$ son los ángulos que $\vec{W}$ forma con los ejes $x$, $y$, y $z$ respectivamente, y $|\vec{W}|$ es la magnitud del vector.
#
# Con lo anterior, para un vector $\vec{W}$ dado, $\vec{W}=w_x\vec{i}+w_y\vec{j}+w_z\vec{k}$, tenemos:
#
# $$\vec{W}=|\vec{W}|\cdot \cos(\alpha)\vec{i}+|\vec{W}|\cdot \cos(\beta)\vec{j}+|\vec{W}|\cdot \cos(\gamma)\vec{j}$$
#
#
# ***Aplicaciones***
#
# - **En Física**: La descomposición de vectores es esencial para analizar fuerzas, velocidades y otros vectores en diferentes direcciones.
# - **En Ingeniería**: Se utiliza para descomponer fuerzas y movimientos en sus componentes para facilitar el análisis de estructuras o maquinarias.

# %% [markdown]
# ### Ejemplos - Operaciones con vectores

# %% [markdown]
# ***Ejemplo 1: Suma de Vectores en 3D***
#
# Dado $\vec{a} = (3, 4, 5)$ y $\vec{b} = (1, 2, 3)$, encuentre $\vec{a} + \vec{b}$.
#
# - **Solución:**
# $$ \vec{a} + \vec{b} = (3 + 1, 4 + 2, 5 + 3) = (4, 6, 8) $$

# %% [markdown]
# ***Ejemplo 2: Producto Escalar en 3D***
#
# Dado $\vec{c} = (2, 3, 4)$ y $\vec{d} = (-1, 4, 5)$, calcule el producto escalar $\vec{c} \cdot \vec{d}$.
#
# - **Solución:**
# $$ \vec{c} \cdot \vec{d} = 2 \times (-1) + 3 \times 4 + 4 \times 5 = -2 + 12 + 20 = 30 $$

# %% [markdown]
# ***Ejemplo 3: Magnitud de un Vector en 3D***
#
# Calcule la magnitud del vector $\vec{e} = (6, 8, 10)$.
#
# - **Solución:**
# $$ \| \vec{e} \| = \sqrt{6^2 + 8^2 + 10^2} = \sqrt{36 + 64 + 100} = \sqrt{200} = 14.14 $$

# %% [markdown]
# ***Ejemplo 4: Vector Unitario en 3D***
#
# Encuentre el vector unitario en la dirección del vector $\vec{f} = (4, 3, 2)$.
#
# - **Solución:**
# Primero, calcule la magnitud de $\vec{f}$:
# $$ \| \vec{f} \| = \sqrt{4^2 + 3^2 + 2^2} = \sqrt{16 + 9 + 4} = \sqrt{29} = 5.39 $$
# Ahora, divida $\vec{f}$ por su magnitud para obtener el vector unitario:
# $$ \hat{f} = \frac{\vec{f}}{\| \vec{f} \|} = \left( \frac{4}{5.39}, \frac{3}{5.39}, \frac{2}{5.39} \right) = (0.74, 0.56, 0.37) $$

# %% [markdown]
# ***Ejemplo 5: Dirección de un Vector en 3D***
#
# Determine los ángulos que forma el vector $\vec{g} = (3, 4, 5)$ con los ejes X, Y y Z.
#
# - **Solución:**
# Los ángulos $\theta_x$, $\theta_y$, y $\theta_z$ con los ejes X, Y y Z respectivamente son:
# $$ \theta_x = \arccos\left(\frac{3}{\sqrt{3^2 + 4^2 + 5^2}}\right), \theta_y = \arccos\left(\frac{4}{\sqrt{3^2 + 4^2 + 5^2}}\right), \theta_z = \arccos\left(\frac{5}{\sqrt{3^2 + 4^2 + 5^2}}\right) $$
#
# Vamos a calcular estos ángulos.
#
#
# Los ángulos que forma el vector $\vec{g} = (3, 4, 5)$ con los ejes X, Y y Z son aproximadamente:
#
# - Con el eje X: $ 64.90^{\circ} $
# - Con el eje Y: $ 55.55^\circ $
# - Con el eje Z: $ 45.00^\circ $

# %% [markdown]
# ***Ejemplo 6:***
#
# Dado $\vec{a} = (1, 2, 3)$ y $\vec{b} = (4, 5, 6)$, calculamos el producto vectorial $\vec{a} \times \vec{b}$.
#
# Para esto, usamos el determinante:
# $$
# \vec{a} \times \vec{b}=\left|\begin{array}{ccc}
# \vec{i} & \vec{j} & \vec{k} \\
# 1 & 2 & 3 \\
# 4 & 5 & 6
# \end{array}\right|
# $$
#
# El desarrollo del determinante nos lleva a:
# $$
# \vec{a} \times \vec{b} = \vec{i}(2\cdot6 - 3\cdot5) - \vec{j}(1\cdot6 - 3\cdot4) + \vec{k}(1\cdot5 - 2\cdot4)
# $$
# $$
# = \vec{i}(12 - 15) - \vec{j}(6 - 12) + \vec{k}(5 - 8)
# $$
# $$
# = -3\vec{i} + 6\vec{j} - 3\vec{k}
# $$
#
# Por lo tanto, $\vec{a} \times \vec{b} = (-3, 6, -3)$.

# %% [markdown]
# ***Ejemplo 7:***
#
# Dado $\vec{c} = (3, -3, 1)$ y $\vec{d} = (4, 9, 2)$, calculamos el producto vectorial $\vec{c} \times \vec{d}$.
#
# Usamos de nuevo el determinante:
# $$
# \vec{c} \times \vec{d}=\left|\begin{array}{ccc}
# \vec{i} & \vec{j} & \vec{k} \\
# 3 & -3 & 1 \\
# 4 & 9 & 2
# \end{array}\right|
# $$
#
# Desarrollando el determinante, obtenemos:
# $$
# \vec{c} \times \vec{d} = \vec{i}((-3)\cdot2 - 1\cdot9) - \vec{j}(3\cdot2 - 1\cdot4) + \vec{k}(3\cdot9 - (-3)\cdot4)
# $$
# $$
# = \vec{i}(-6 - 9) - \vec{j}(6 - 4) + \vec{k}(27 + 12)
# $$
# $$
# = -15\vec{i} - 2\vec{j} + 39\vec{k}
# $$
#
# Así, $\vec{c} \times \vec{d} = (-15, -2, 39)$.

# %% [markdown]
# ***Ejemplo 8:*** Encontrar la suma de los vectores $\vec{A}$ y $\vec{B}$ mostrados en la figura, donde $|\vec{A}|= 4 m$ y $|\vec{B}| = 3.5 m$
#
# Para sumar los vectores $ \vec{A} $ y $ \vec{B} $, primero debemos descomponer cada vector en sus componentes $x$ e $y$ utilizando las magnitudes dadas y los ángulos proporcionados por la figura.
#
# - ***Descomposición de Vectores:***
#
#   Para $ \vec{A} $, con una magnitud de $ |A| = 4 $ metros y un ángulo de $15^\circ{}$ con respecto al eje $x$ positivo:
# - Componente $x$: $ A_x = |A| \cdot \cos(15^\circ{}) = 4 \cdot \cos(15^\circ{}) $
# - Componente $y$: $ A_y = |A| \cdot \sin(15^\circ{}) = 4 \cdot \sin(15^\circ{}) $
#
#   Para $ \vec{B} $, con una magnitud de $ |B| = 3.5 $ metros y un ángulo de $45^\circ{}$ con respecto al eje $x$ positivo:
# - Componente x: $ B_x = |B| \cdot \cos(45^\circ{}) = 3.5 \cdot \cos(45^\circ{}) $
# - Componente y: $ B_y = |B| \cdot \sin(45^\circ{}) = 3.5 \cdot \sin(45^\circ{}) $
#
# - ***Suma de Componentes:***
#
#   La suma de los vectores $ \vec{A} $ y $ \vec{B} $, denotada como $ \vec{R} $ (el vector resultante), se obtiene sumando las componentes correspondientes:
#
# - Componente $x$ del vector resultante: $ R_x = A_x + B_x $
# - Componente $y$ del vector resultante: $ R_y = A_y + B_y $
#
# - ***Magnitud y Dirección del Vector Resultante:***
#
#   Una vez que tenemos las componentes del vector resultante, podemos calcular su magnitud y dirección:
#
# - Magnitud: $ |R| = \sqrt{R_x^2 + R_y^2} $
# - Dirección: $ \theta_R = \arctan\left(\frac{R_y}{R_x}\right) $ (ángulo con respecto al eje $x$ positivo)
#
#   Con estas fórmulas, podemos calcular las componentes del vector resultante, su magnitud y su dirección.
#
# - ***Cálculos:***
#
# $$ A_x = 4 \cdot \cos(15^\circ{}) $$
# $$ A_y = 4 \cdot \sin(15^\circ{}) $$
# $$ B_x = 3.5 \cdot \cos(45^\circ{}) $$
# $$ B_y = 3.5 \cdot \sin(45^\circ{}) $$
#
# $$ R_x = A_x + B_x $$
# $$ R_y = A_y + B_y $$
#
# $$ |R| = \sqrt{R_x^2 + R_y^2} $$
# $$ \theta_R = \arctan\left(\frac{R_y}{R_x}\right) $$
#
# Ahora realizaremos los cálculos con los valores exactos para los ángulos dados.
#
# Para sumar los vectores $\vec{A}$ y $\vec{B}$ debemos primero encontrar sus componentes en el eje $x$ y en el eje $y$. Luego sumamos las componentes correspondientes para obtener el vector resultante $\vec{R}$.
#
# Los vectores $\vec{A}$ y $\vec{B}$ tienen magnitudes de $4 m$ y $3.5 m$, respectivamente. Los ángulos con el eje $x$ son de $15^\circ{}$ para $\vec{A}$ y $45^\circ{}$ para $\vec{B}$.
#
# - ***Componentes de $\vec{A}$:***
#
# $$ A_x = |A| \cos(15^\circ{}) = 4 \cos(15^\circ{}) $$
# $$ A_y = |A| \sin(15^\circ{}) = 4 \sin(15^\circ{}) $$
#
# - ***Componentes de $\vec{B}$:***
#
# $$ B_x = |B| \cos(45^\circ{}) = 3.5 \cos(45^\circ{}) $$
# $$ B_y = |B| \sin(45^\circ{}) = 3.5 \sin(45^\circ{}) $$
#
# Con los valores exactos de las funciones trigonométricas para los ángulos dados, los componentes serían:
#
# $$ A_x = 4 \cos(15^\circ{}) \approx 4 \times 0.9659 = 3.8636 $$
# $$ A_y = 4 \sin(15^\circ{}) \approx 4 \times 0.2588 = 1.0352 $$
# $$ B_x = 3.5 \cos(45^\circ{}) = 3.5 \times \frac{\sqrt{2}}{2} \approx 3.5 \times 0.7071 = 2.47485 $$
# $$ B_y = 3.5 \sin(45^\circ{}) = 3.5 \times \frac{\sqrt{2}}{2} \approx 3.5 \times 0.7071 = 2.47485 $$
#
# Ahora sumamos las componentes para obtener $\vec{R}$:
#
# $$ R_x = A_x + B_x = 3.8636 + 2.47485 $$
# $$ R_y = A_y + B_y = 1.0352 + 2.47485 $$
#
# Calculamos las sumas:
#
# $$ R_x = 6.33845 $$
# $$ R_y = 3.51005 $$
#
# La magnitud del vector resultante $\vec{R}$ es:
#
# $$ |\vec{R}| = \sqrt{R_x^2 + R_y^2} $$
# $$ |\vec{R}| \approx \sqrt{6.33845^2 + 3.51005^2} $$
# $$ |\vec{R}| \approx \sqrt{40.1766 + 12.3204} $$
# $$ |\vec{R}| \approx \sqrt{52.497} $$
# $$ |\vec{R}| \approx 7.244 \text{ m} $$
#
# El ángulo $\theta_R$ que forma $\vec{R}$ con el eje $x$ es:
#
# $$ \theta_R = \arctan\left(\frac{R_y}{R_x}\right) $$
# $$ \theta_R \approx \arctan\left(\frac{3.51005}{6.33845}\right) $$
# $$ \theta_R \approx \arctan(0.554) $$
# $$ \theta_R \approx 29.3^\circ{} $$
#
# Por lo tanto, el vector resultante $\vec{R}$ tiene una magnitud aproximada de $7.244 m$ y forma un ángulo de aproximadamente $29.3^\circ{}$ con el eje $x$.

# %% [markdown]
# ***Ejemplo 9:*** Encontrar la fuerza resultante en el gancho.
#
# <p float="center">
#   <img src="https://github.com/carlosalvarezh/Geometria_Analitica_Vectorial/blob/main/Images/VectorFuerza00.PNG?raw=true" width="150" />
# </p>
#
# Observando la imagen, podemos ver que la fuerza de $800 lb$ actúa hacia arriba y la izquierda, formando un ángulo de $60^\circ$ con la horizontal. La fuerza de $500 lb$ actúa hacia abajo y la derecha, formando un ángulo de $35^\circ$ con la horizontal.
#
# Vamos a calcular las componentes de cada fuerza:
#
# ***Para la fuerza de 800 lb:***
# - Componente horizontal ($F_{800x}$): $ 800 \cdot \cos(60^\circ) = 800 \cdot 0.5 = 400 $ lb (a la derecha)
# - Componente vertical ($F_{800y}$): $ 800 \cdot \sin(60^\circ) = 800 \cdot \sqrt{3}/2 \approx 800 \cdot 0.866 = 692.8 $ lb (hacia arriba)
#
# ***Para la fuerza de 500 lb:***
# - Componente horizontal ($F_{500x}$): $ 500 \cdot \cos(35^\circ) \approx 500 \cdot 0.819 \approx 409.5 $ lb (a la derecha)
# - Componente vertical ($F_{500y}$): $ -500 \cdot \sin(35^\circ) \approx -500 \cdot 0.574 \approx -287 $ lb (hacia abajo, de ahí el signo negativo)
#
# Ahora, sumamos las componentes horizontales y verticales de ambas fuerzas para obtener la fuerza resultante. Para la componente horizontal, debemos considerar que las fuerzas actúan en direcciones opuestas, y lo mismo para la componente vertical, ya que una actúa hacia arriba y la otra hacia abajo.
#
# ***Fuerza Resultante:***
# - $ R_x = F_{800x} + F_{500x} = 400 + 409.5 \approx 809.5 $ lb (hacia la derecha)
# - $ R_y = F_{800y} + F_{500y} = 692.8 - 287 \approx 405.8 $ lb (hacia arriba)
#
# Finalmente, calculamos la magnitud de la fuerza resultante usando el teorema de Pitágoras:
#
# $$ R = \sqrt{R_x^2 + R_y^2} \approx \sqrt{(809.5)^2 + 405.8^2} \approx \sqrt{655242.25 + 164676.64} \approx \sqrt{819918.89} \approx 905.49 \text{ lb} $$
#
# La dirección, el ángulo $\theta$ que la fuerza resultante forma con la horizontal, se calcula como:
#
# $$ \theta = \arctan\left(\frac{R_y}{R_x}\right) \approx \arctan\left(\frac{405.8}{809.5}\right) \approx \arctan(0.501) \approx 0.4646 \text{ rads}$$
#
# El cálculo anterior está expresado en radianes. Para pasarlo a grados multiplicamos por $180/\pi$
#
# $$\theta \approx 0.4646 \times 180 / \pi \approx 26.62^\circ$$
#
# Así que la fuerza resultante tiene una magnitud aproximada de $905.49 lb$ y forma un ángulo de aproximadamente $26.62$ grados con la horizontal hacia arriba y a la derecha.

# %% [markdown]
# ***Ejemplo 10:*** Un lanchón es arrastrado por dos remolcadores. Si la resultante de las fuerzas ejercidas por los remolcadores es una fuerza de $5000 lb$ dirigida a lo largo del eje del lanchón, determine: la tensión en cada una de las cuerdas, sabiendo que $\alpha=45^\circ$.
#
# <p float="center">
#   <img src="https://github.com/carlosalvarezh/Geometria_Analitica_Vectorial/blob/main/Images/VectorFuerza01.PNG?raw=true" width="250" />
# </p>
#
# Las tensiones en las cuerdas pueden representarse por dos vectores: $ \vec{T_A} $ y $ \vec{T_C} $, que forman ángulos de $30°$ y $45°$ con la horizontal, respectivamente.
#
# Para la cuerda 1 (vector $ \vec{T_A} $):
# - Componente horizontal ($ T_{Ax} $): $ T_A \cos(30°) $
# - Componente vertical ($ T_{Ay} $): $ T_A \sin(30°) $
#
# Para la cuerda 2 (vector $ \vec{T_C} $):
# - Componente horizontal ($ T_{Cx} $): $ T_C \cos(45°) $
# - Componente vertical ($ T_{Cy} $): $ T_C \sin(45°) $
#
# La suma de las componentes horizontales de ambas tensiones debe ser igual a la fuerza resultante que actúa a lo largo del eje del lanchón, y las componentes verticales deben sumar cero ya que no hay movimiento vertical.
#
# Por lo tanto, las ecuaciones de equilibrio son:
#
# Horizontal:
# $$ T_A \cos(30°) + T_C \cos(45°) = 5000 \, \text{lb} $$
#
# Vertical:
# $$ T_A \sin(30°) = T_C \sin(45°) $$
#
# De la segunda ecuación, podemos aislar una de las tensiones en términos de la otra debido a que el lanchón está en equilibrio vertical y no se acelera hacia arriba o hacia abajo:
#
# $$ T_A = T_C \frac{\sin(45°)}{\sin(30°)} $$
#
# Ahora sustituimos $ T_A $ de la segunda ecuación en la primera y resolvemos para $ T_C $:
#
# $$ T_C \frac{\sin(45°)}{\sin(30°)} \cos(30°) + T_C \cos(45°) = 5000 $$
#
# Con $ \sin(30°) = 0.5 $, $ \sin(45°) = \cos(45°) = \frac{\sqrt{2}}{2} $, y $ \cos(30°) = \frac{\sqrt{3}}{2} $, podemos resolver $ T_C $ y luego usarlo para encontrar $ T_A $. Reemplazando estos valores:
#
# $$T_C \frac{\frac{\sqrt{2}}{2}}{\frac{1}{2}}\frac{\sqrt{3}}{2}+T_C\frac{\sqrt{2}}{2}=5000$$
# $$T_C\sqrt{2}\sqrt{3}+T_C\sqrt{2}=10000$$
# $$T_C=\frac{10000}{\sqrt{2}\sqrt{3}+\sqrt{2}}\approx 2588.19$$
#
# Con este valor, reemplazamos en la ecuación de $T_A$:
#
# $$ T_A = T_C \frac{\sin(45°)}{\sin(30°)} \approx 2588.19 \sqrt{2} \approx 3660.25$$

# %% [markdown]
# ***Ejemplo 11:*** Si se sabe que $\alpha = 35^\circ$, determine la resultante de las tres fuerzas mostradas en la figura.
#
# <p float="center">
#   <img src="https://github.com/carlosalvarezh/Geometria_Analitica_Vectorial/blob/main/Images/VectorFuerza02.PNG?raw=true" width="250" />
# </p>
#
# Para determinar la resultante de las tres fuerzas mostradas en la figura, descomponemos cada fuerza en sus componentes horizontal y vertical y luego sumamos todas las componentes horizontales y verticales por separado.
#
# Dadas las fuerzas y los ángulos:
# - Fuerza de $200 N$ actuando a un ángulo de $ 35^\circ $ hacia abajo y a la izquierda.
# - Fuerza de $100 N$ actuando a un ángulo de $ 35^\circ $ hacia abajo y a la derecha.
# - Fuerza de $150 N$ actuando a un ángulo de $ 65^\circ $ hacia abajo y a la derecha.
#
# Para cada fuerza, descompondremos en componentes horizontal ($x$) y vertical ($y$), teniendo en cuenta que las componentes a la izquierda y hacia abajo serán negativas:
#
# ***Fuerza de 200 N (actuando a 35° hacia abajo y a la izquierda):***
# - Componente horizontal ($ F_{200x} $): $ -200 \cos(35°) $ (negativo hacia la izquierda)
# - Componente vertical ($ F_{200y} $): $ -200 \sin(35°) $ (negativo hacia abajo)
#
# ***Fuerza de 100 N (actuando a 35° hacia abajo y a la derecha):***
# - Componente horizontal ($ F_{100x} $): $ 100 \cos(35°) $ (positivo hacia la derecha)
# - Componente vertical ($ F_{100y} $): $ -100 \sin(35°) $ (negativo hacia abajo)
#
# ***Fuerza de 150 N (actuando a 65° hacia abajo y a la derecha):***
# - Componente horizontal ($ F_{150x} $): $ 150 \cos(65°) $ (positivo hacia la derecha)
# - Componente vertical ($ F_{150y} $): $ -150 \sin(65°) $ (negativo hacia abajo)
#
# Sumamos las componentes de las tres fuerzas para obtener la resultante horizontal ($ R_x $) y vertical ($ R_y $):
#
# $$ R_x = F_{200x} + F_{100x} + F_{150x} $$
# $$ R_y = F_{200y} + F_{100y} + F_{150y} $$
#
# La magnitud de la fuerza resultante será $ R = \sqrt{R_x^2 + R_y^2} $, y el ángulo $ \theta $ que forma con la horizontal se calcula como $ \theta = \arctan\left(\frac{R_y}{R_x}\right) $.
#
# Realizando los cálculos con los valores trigonométricos exactos:
#
# $$ F_{200x} = -200 \cos(35°) \approx -200 \times 0.8192 \approx -163.84 \, \text{N} $$
# $$ F_{200y} = -200 \sin(35°) \approx -200 \times 0.5736 \approx -114.72 \, \text{N} $$
#
# $$ F_{100x} = 100 \cos(35°) \approx 100 \times 0.8192 \approx 81.92 \, \text{N} $$
# $$ F_{100y} = -100 \sin(35°) \approx -100 \times 0.5736 \approx -57.36 \, \text{N} $$
#
# $$ F_{150x} = 150 \cos(65°) \approx 150 \times 0.4226 \approx 63.39 \, \text{N} $$
# $$ F_{150y} = -150 \sin(65°) \approx -150 \times 0.9063 \approx -135.945 \, \text{N} $$
#
# Sumamos las componentes para obtener la fuerza resultante:
#
# $$ R_x = (-163.84) + 81.92 + 63.39 \approx -18.53 \, \text{N} $$
# $$ R_y = (-114.72) + (-57.36) + (-135.945) \approx -308.025 \, \text{N} $$
#
# La magnitud de la fuerza resultante es:
#
# $$ R \approx \sqrt{(-18.53)^2 + (-308.025)^2} $$
# $$ R \approx \sqrt{343.1209 + 94882.7406} $$
# $$ R \approx \sqrt{95226} $$
# $$ R \approx 308.588 \, \text{N} $$
#
# El ángulo $ \theta $ que la resultante forma con la horizontal será:
#
# $$ \theta \approx \arctan\left(\frac{-308.025}{-18.53}\right) $$
# $$ \theta \approx \arctan(16.625) \text{rads} \approx 86.55^\circ$$
#
# Dado que tanto $ R_x $ como $ R_y $ son negativas, la fuerza resultante apunta hacia abajo y hacia la izquierda. El ángulo $ \theta $ debe ser medido desde la horizontal hacia la fuerza resultante en el cuadrante correcto.

# %% [markdown]
# ***Ejemplo 12:*** El cilindro hidráulico $BD$ ejerce una fuerza $P$ sobre el elemento $ABC$, dicha fuerza está dirigida a lo largo de la línea $BD$. Si se sabe que $P$ debe tener una componente de $750 N$ perpendicular al elemento $ABC$, determine:
# a) la magnitud de la fuerza $P$,
# b) su componente paralela a $ABC$.
#
# <p float="center">
#   <img src="https://github.com/carlosalvarezh/Geometria_Analitica_Vectorial/blob/main/Images/VectorFuerza03.PNG?raw=true" width="250" />
# </p>
#
# Para resolver este problema, primero necesitamos analizar las fuerzas que actúan sobre el elemento $ABC$. La fuerza $P$, ejercida por el cilindro hidráulico $BD$, está dirigida a lo largo de la línea $BD$.
#
# Dada la información, sabemos que la componente de la fuerza $P$ perpendicular al elemento $ABC$ es de $750 N$. Necesitamos encontrar la magnitud total de $P$ y la componente de $P$ paralela a $ABC$.
#
# Podemos usar trigonometría para resolver esto. Dibujamos un triángulo de fuerzas donde la fuerza $P$ es la hipotenusa, la componente perpendicular es uno de los lados y la componente paralela es el otro lado. El ángulo que forma la fuerza $P$ con la perpendicular a $ABC$ es de $ 60^\circ $.
#
# La componente perpendicular de $P$ es opuesta al ángulo de $ 60^\circ $, y podemos usar esto para encontrar la magnitud total de $P$ con la ley de senos o directamente con funciones trigonométricas:
#
# $$ P_{perpendicular} = P \cdot \sin(60^\circ) $$
#
# Reorganizando esta fórmula para resolver para $P$, obtenemos:
#
# $$ P = \frac{P_{perpendicular}}{\sin(60^\circ)} $$
#
# Dado que $ P_{perpendicular} = 750 $ N, calculamos $P$:
#
# $$ P = \frac{750 \, \text{N}}{\sin(60^\circ)} $$
# $$ P = \frac{750 \, \text{N}}{\frac{\sqrt{3}}{2}} $$
# $$ P = 750 \, \text{N} \cdot \frac{2}{\sqrt{3}} $$
# $$ P \approx 866.03 \, \text{N} $$
#
# La magnitud de la fuerza $P$ es aproximadamente $866.03 N$.
#
# Para encontrar la componente de la fuerza $P$ paralela a $ABC$ (denotada como $ P_{paralela} $), usamos la función coseno ya que es adyacente al ángulo de $ 60^\circ $:
#
# $$ P_{paralela} = P \cdot \cos(60^\circ) $$
# $$ P_{paralela} = 866.03 \, \text{N} \cdot \frac{1}{2} $$
# $$ P_{paralela} = 433.02 \, \text{N} $$
#
# Por lo tanto, la componente paralela de $P$ a lo largo de $ABC$ es aproximadamente $433.02 N$.

# %% [markdown]
# ***Ejemplo 13:*** Las fuerzas $\overrightarrow{F_1}, \overrightarrow{F_2}$ y $\overrightarrow{F_3}$ se aplican como se muestra en la figura. Sabiendo que $\theta_1=\left|45^{\circ}-n\right|$ y que la fuerza resultante es $\vec{R}=(-5,30,5) \mathrm{lb}$. Determinar la magnitud y coseno directores de $\overrightarrow{F_3}$.
#
# <p float="center">
#   <img src="https://github.com/carlosalvarezh/Geometria_Analitica_Vectorial/blob/main/Images/VectorFuerza04.PNG?raw=true" width="250" />
# </p>
#
# Para determinar la magnitud y los cosenos directores de la fuerza $ F_3 $, primero necesitamos establecer un sistema de ecuaciones basado en las componentes de las fuerzas y la fuerza resultante $ R = (-5, 30, 5) $ lb.
#
# Sabemos que la suma vectorial de las fuerzas $ F_1 $, $ F_2 $, y $ F_3 $ es igual a $ R $. La fuerza $ F_1 $ tiene una magnitud de $10 lb$ y actúa en la dirección positiva del eje $x$, por lo que sus componentes son $ (10, 0, 0) $. La fuerza $ F_2 $ tiene una magnitud de $7 lb$ y actúa en la dirección negativa del eje $z$, por lo que sus componentes son $ (0, 0, -7) $.
#
# Las componentes de $ F_3 $ en términos de su magnitud $ F_3 $ y los ángulos desconocidos serían $ (F_{3x}, F_{3y}, F_{3z}) $. Dado que no tenemos el ángulo de $ F_3 $ con respecto a los ejes $y$ y $z$, pero sabemos que debe satisfacer las condiciones de equilibrio con $ F_1 $ y $ F_2 $, podemos escribir las ecuaciones de equilibrio de la siguiente manera:
#
# $$ F_{1x} + F_{2x} + F_{3x} = R_x $$
# $$ F_{1y} + F_{2y} + F_{3y} = R_y $$
# $$ F_{1z} + F_{2z} + F_{3z} = R_z $$
#
# Sustituimos los valores conocidos:
#
# $$ 10 + 0 + F_{3x} = -5 $$
# $$ 0 + 0 + F_{3y} = 30 $$
# $$ 0 - 7 + F_{3z} = 5 $$
#
# De donde obtenemos las componentes de $ F_3 $:
#
# $$ F_{3x} = -5 - 10 = -15 $$
# $$ F_{3y} = 30 $$
# $$ F_{3z} = 5 + 7 = 12 $$
#
# Ahora podemos calcular la magnitud de $ |F_3| $ usando el teorema de Pitágoras:
#
# $$|F_3|= \sqrt{F_{3x}^2 + F_{3y}^2 + F_{3z}^2} = \sqrt{(-15)^2 + 30^2 + 12^2} = \sqrt{225 + 900 + 144} = \sqrt{1269} F_3 \approx 35.62 \text{ lb}$$
#
# Para encontrar los cosenos directores, que son los cosenos de los ángulos entre la fuerza y los ejes $x$, $y$, y $z$, respectivamente, usamos:
#
# $$ \cos(\alpha) = \frac{F_{3x}}{|F_3|} = \frac{-15}{35.62} \approx -0.421 $$
# $$ \cos(\beta) = \frac{F_{3y}}{|F_3|} = \frac{30}{35.62} \approx 0.842 $$
# $$ \cos(\gamma) = \frac{F_{3z}}{|F_3|} = \frac{12}{35.62} \approx 0.337 $$
#
# Una vez obtenidos estos resultados verificamos si se cumple que:
#
# $$\cos^2(\alpha) + \cos^2(\beta) + \cos^2(\gamma)= 1$$
# $$(-0.421)^2 + 0.842^2 + 0.337^2 \approx 0.177241+0.709384+0.113569 \approx 1.000194$$
#
# observamos que es un valor muy cercano a la unidad. No es igual debido a los errores de redondeo en los cálculos.
#
# Estos serían los cosenos directores de la fuerza $ F_3 $, y su magnitud es aproximadamente $35.62$ lb.

# %% [markdown]
# ***Ejemplo 14:*** Encuentre el ángulo entre el vector $\vec{A}$ que de los puntos $(0,-2,3)$ a $(7,11-3)$ y vector $\vec{B}=\frac{7}{2} \hat{\mathbf{l}}-\frac{1}{4} \hat{\mathbf{j}}+3 \hat{\mathbf{k}}$.
#
# Para encontrar el ángulo entre dos vectores, primero necesitamos conocer las componentes de ambos vectores. Luego podemos usar la fórmula del producto punto, que es definida como:
#
# $$ \vec{A} \cdot \vec{B} = |\vec{A}| |\vec{B}| \cos(\theta) $$
#
# Donde $ \theta $ es el ángulo entre los vectores.
#
# El vector $ \vec{A} $ puede ser encontrado restando las coordenadas del punto final menos las coordenadas del punto inicial, así que sus componentes son:
#
# $$ \vec{A} = (7 - 0) \hat{\mathbf{i}} + (11 - (-2)) \hat{\mathbf{j}} + (-3 - 3) \hat{\mathbf{k}} $$
# $$ \vec{A} = 7 \hat{\mathbf{i}} + 13 \hat{\mathbf{j}} - 6 \hat{\mathbf{k}} $$
#
# Las componentes del vector $ \vec{B} $ están dadas directamente en la pregunta:
#
# $$ \vec{B} = \frac{7}{2} \hat{\mathbf{i}} - \frac{1}{4} \hat{\mathbf{j}} + 3 \hat{\mathbf{k}} $$
#
# Calculamos el producto punto $ \vec{A} \cdot \vec{B} $:
#
# $$ \vec{A} \cdot \vec{B} = (7)(\frac{7}{2}) + (13)(-\frac{1}{4}) + (-6)(3) = 3.25$$
#
# Calculamos las magnitudes de $ \vec{A} $ y $ \vec{B} $:
#
# $$ |\vec{A}| = \sqrt{7^2 + 13^2 + (-6)^2} = \sqrt{254}$$
# $$ |\vec{B}| = \sqrt{\left(\frac{7}{2}\right)^2 + \left(-\frac{1}{4}\right)^2 + 3^2} = \frac{\sqrt{341}}{4}$$
#
# Después, usamos estos valores para encontrar el ángulo $ \theta $ entre $ \vec{A} $ y $ \vec{B} $:
#
# $$ \cos(\theta) = \frac{\vec{A} \cdot \vec{B}}{|\vec{A}| |\vec{B}|} $$
#
# $$ \cos(\theta) = \frac{3.25}{\sqrt{254} \cdot \frac{\sqrt{341}}{4}} $$
# $$ \cos(\theta) = \frac{3.25 \cdot 4}{\sqrt{254} \cdot \sqrt{341}} $$
# $$ \cos(\theta) = \frac{13}{\sqrt{86234}} $$
#
# Ahora podemos encontrar el ángulo $ \theta $ calculando su arco coseno:
#
# $$ \theta = \arccos\left(\frac{\vec{A} \cdot \vec{B}}{|\vec{A}| |\vec{B}|}\right) = \arccos\left(\frac{13}{\sqrt{86234}}\right) \approx 1.5265 \text{ rads}$$
#
# Por último, pasamos ese valor de radianes a grados:
#
# $$ \theta \approx 1.5265 \text{rads} \times \frac{180}{\pi} \approx 87.46^\circ$$

# %% [markdown]
# ## Ecuaciones de la Recta en 3D

# %% [markdown]
# ### Ecuaciones de la recta en 3D

# %% [markdown]
# <p float="center">
#   <img src="https://github.com/carlosalvarezh/Geometria_Analitica_Vectorial/blob/main/Images/Recta3D.PNG?raw=true" width="200" />
# </p>
#
# Consideremos la recta $ l $, que pasa por dos puntos dados $ P_0 $ y $ P $. Estos puntos se definen por sus vectores posición $ \overrightarrow{r_0} $ y $ \vec{r} $ respectivamente, de la siguiente manera:
# $$
# \begin{aligned}
# & \overrightarrow{r_0} = x_0 \hat{\mathbf{i}} + y_0 \hat{\mathbf{j}} + z_0 \hat{\mathbf{k}}, \\
# & \vec{r} = x \hat{\mathbf{i}} + y \hat{\mathbf{j}} + z \hat{\mathbf{k}}.
# \end{aligned}
# $$
#
# Introducimos un vector $ \vec{A} $, que representa el desplazamiento desde $ P_0 $ a $ P $, definido como:
# $$
# \vec{A} = \vec{r} - \overrightarrow{r_0}.
# $$
#
# El vector dirección $ \vec{V} $, paralelo a la recta $ l $, con componentes conocidas $ a $, $ b $ y $ c $, se expresa así:
# $$
# \vec{V} = a \hat{\mathbf{i}} + b \hat{\mathbf{j}} + c \hat{\mathbf{k}}.
# $$
#
# Establecemos que $ \vec{A} $ es proporcional a $ \vec{V} $ a través de un escalar $ t $:
# $$
# \vec{A} = \vec{r} - \overrightarrow{r_0} = t \vec{V}.
# $$
#
# Despejando $ \vec{r} $, obtenemos la ecuación vectorial de la recta:
# $$
# \vec{r} = \overrightarrow{r_0} + t \vec{V}.
# $$
#
# Desarrollando todos los componentes vectoriales, obtenemos la ***ecuación vectorial de la recta**** en 3D:
# $$
# x \hat{\mathbf{i}} + y \hat{\mathbf{j}} + z \hat{\mathbf{k}} = x_0 \hat{\mathbf{i}} + y_0 \hat{\mathbf{j}} + z_0 \hat{\mathbf{k}} + t(a \hat{\mathbf{i}} + b \hat{\mathbf{j}} + c \hat{\mathbf{k}}).
# $$
#
# Esta ecuación vectorial puede convertirse en su forma escalar, resultando en tres ***[ecuaciones paramétricas](https://en.wikipedia.org/wiki/Parametric_equation)***:
# $$
# \begin{aligned}
# & x = x_0 + at, \\
# & y = y_0 + bt, \\
# & z = z_0 + ct.
# \end{aligned}
# $$
#
# Despejando $ t $ en cada una de las ecuaciones paramétricas y luego igualando estos valores, obtenemos la ***ecuación de la recta en su forma simétrica***:
# $$
# \frac{x - x_0}{a} = \frac{y - y_0}{b} = \frac{z - z_0}{c}.
# $$
#
# Esta ecuación simétrica proporciona una descripción completa y concisa de la recta en un espacio tridimensional.

# %% [markdown]
# ***Ejemplo01:*** Encontrar las tres formas de la recta que pasa por los puntos $A(−5,4,1)$ y $B(9,10,−5)$.
#
# Para encontrar las tres formas de la ecuación de la recta que pasa por los puntos $ A(-5, 4, 1) $ y $ B(9, 10, -5) $, primero obtenemos el vector dirección:
#
# - **Calcular el vector dirección $ \vec{V} $**: Este vector se obtiene restando las coordenadas de $ A $ de las de $ B $.
#
# $$ \vec{V} = B - A = (9 - (-5), 10 - 4, -5 - 1) = (14, 6, -6)$$
#
# - **Ecuación Vectorial**: Utilizando el punto $ A $ y el vector $ \vec{V} $, la ecuación vectorial es de la forma $ \vec{r} = \vec{r_0} + t\vec{V} $, donde $ \vec{r_0} $ es el vector posición de $ A $, llegando a:
#
# $$\vec{r} = (-5 \hat{\mathbf{i}} + 4 \hat{\mathbf{j}} + 1 \hat{\mathbf{k}}) + t(14 \hat{\mathbf{i}} + 6 \hat{\mathbf{j}} - 6 \hat{\mathbf{k}})$$
#
# - **Ecuación Paramétrica**: Desarrollamos la ecuación vectorial en sus componentes $ x $, $ y $, y $ z $.
#    $$
#    \begin{aligned}
#    x &= -5 + 14t, \\
#    y &= 4 + 6t, \\
#    z &= 1 - 6t.
#    \end{aligned}
#    $$
#
# - **Ecuación Simétrica**: Despejamos $ t $ en las ecuaciones paramétricas y las igualamos, la ecuación simétrica es:
#    $$\frac{x + 5}{14} = \frac{y - 4}{6} = \frac{z - 1}{-6}$$
#
# Estas son las tres formas de la ecuación de la recta que pasa por los puntos $ A(-5, 4, 1) $ y $ B(9, 10, -5) $.

# %% [markdown]
# ### Distancia de un punto a una línea recta en 3D

# %% [markdown]
# Para calcular la distancia $ D $ de un punto $ P(x, y, z) $ a una línea recta $ l_1 $ en el espacio tridimensional, el proceso involucra varios pasos geométricos y vectoriales.
#
# <p float="center">
#   <img src="https://github.com/carlosalvarezh/Geometria_Analitica_Vectorial/blob/main/Images/DistanciaPuntoRecta3D.PNG?raw=true" width="350" />
# </p>
#
#
# Primero, seleccionamos un punto $ Q $ sobre la recta $ l_1 $ y definimos un vector dirección $ \vec{V_1} $ que caracteriza la recta. A continuación, trazamos un vector $ \overrightarrow{QP} $ que conecta el punto $ Q $ con el punto $ P $. La distancia $ D $ que buscamos es la longitud del segmento perpendicular que va desde $ P $ hasta la recta $ l_1 $.
#
# La clave para determinar $ D $ es usar la propiedad del producto vectorial. El módulo del producto vectorial de dos vectores es igual al producto de sus módulos por el seno del ángulo $ \theta $ entre ellos:
# $$ |\vec{d} \times \overrightarrow{QP}| = |\vec{d}| \cdot |\overrightarrow{QP}| \cdot \sin \theta. $$
#
# El ángulo $ \theta $ aquí es el formado entre el vector dirección $ \vec{d} $ y $ \overrightarrow{QP} $. Para hallar la distancia $ D $, necesitamos expresar $ \sin \theta $ en términos de cantidades conocidas. Recordando que $ \sin \theta $ es la relación entre el lado opuesto a $ \theta $ en un triángulo rectángulo y su hipotenusa, y en nuestro caso, el lado opuesto es la distancia $ D $ y la hipotenusa es $ |\overrightarrow{QP}| $, tenemos:
# $$ \sin \theta = \frac{D}{|\overrightarrow{QP}|}. $$
#
# Al sustituir esta relación en nuestra ecuación inicial y despejar $ D $, obtenemos la fórmula para calcular la distancia del punto $ P $ a la recta:
# $$ D = \frac{|\vec{d} \times \overrightarrow{QP}|}{|\vec{d}|}. $$
#
# Esta fórmula permite calcular la distancia más corta desde un punto dado hasta una línea recta en el espacio tridimensional.

# %% [markdown]
# ***Ejemplo 02:*** Encontrar la distancia entre el punto $(3,-2,1)$ y la recta $l_1: \frac{-x+2}{-2}=\frac{3 y+3}{-6}=z$
#
# Para encontrar la distancia entre un punto y una recta en 3D, seguimos los pasos mencionados anteriormente. En este caso, necesitamos calcular la distancia entre el punto $ P(3, -2, 1) $ y la recta $ l_1 $ definida por la ecuación
# $$ \frac{-x + 2}{-2} = \frac{3y + 3}{-6} = z. $$
#
# 1. **Encontrar un punto en la recta $ l_1 $**: Podemos obtener un punto $ Q $ sobre la recta $ l_1 $ eligiendo un valor para el parámetro (digamos, $ t = 0 $) y sustituyéndolo en la ecuación de la recta.
#
# 2. **Determinar el vector dirección $ \vec{d} $ de la recta**: La ecuación de la recta en su forma simétrica nos da el vector dirección.
#
# 3. **Calcular el vector $ \overrightarrow{QP} $**: Usamos las coordenadas de $ P $ y $ Q $ para encontrar este vector.
#
# 4. **Aplicar la fórmula de la distancia**: La distancia $ D $ se encuentra usando la fórmula
#    $$ D = \frac{|\vec{d} \times \overrightarrow{QP}|}{|\vec{d}|}. $$
#
# Comencemos calculando un punto $ Q $ sobre la recta $ l_1 $ y el vector dirección $ \vec{d} $.
#
# Hemos calculado lo siguiente:
#
# - Un punto $ Q $ en la recta $ l_1 $ es $ (2, -1, 0) $.
# - El vector dirección $ \vec{d} $ de la recta es $ (-2, -6, 1) $.
# - El vector $ \overrightarrow{QP} $ es $ (1, -1, 1) $.
#
# Ahora, aplicaremos la fórmula de la distancia:
# $$ D = \frac{|\vec{d} \times \overrightarrow{QP}|}{|\vec{d}|}. $$
#
# Para ello, primero calcularemos el producto vectorial $ \vec{d} \times \overrightarrow{QP} $ y luego encontraremos su magnitud y la magnitud de $ \vec{d} $. Con estos valores, podremos calcular la distancia $ D $. Procedamos con estos cálculos.
#
# La distancia entre el punto $ (3, -2, 1) $ y la recta
# $$ \frac{-x + 2}{-2} = \frac{3y + 3}{-6} = z $$
# es aproximadamente $ 1.546 $ unidades.

# %% [markdown]
# ### Distancia entre dos rectas en 3D

# %% [markdown]
# La medición de la distancia más corta $D$ entre dos rectas, $l_1$ y $l_2$, en un espacio tridimensional es una tarea que involucra conceptos de geometría vectorial. Esta distancia se define como la longitud del segmento de línea más corto que conecta las dos rectas, siendo perpendicular a ambas.
#
# Para calcular $D$, usamos la siguiente fórmula:
#
# $$
# D = \left| \frac{\left( \vec{V_1} \times \vec{V_2} \right) \cdot \vec{P_1P_2}}{|\vec{V_1} \times \vec{V_2}|} \right|,
# $$
#
# donde:
# - $\vec{V_1}$ es el vector dirección de la recta $l_1$.
# - $\vec{V_2}$ es el vector dirección de la recta $l_2$.
# - $\vec{P_1P_2}$ es el vector que conecta un punto conocido $P_1$ en la recta $l_1$ con un punto conocido $P_2$ en la recta $l_2$.
#
# Es crucial que el producto vectorial $\vec{V_1} \times \vec{V_2}$ sea no nulo (es decir, $|\vec{V_1} \times \vec{V_2}| \neq 0$), lo cual asegura que las rectas no son paralelas.
#
# La fórmula proporciona la distancia proyectando el vector que une los dos puntos en la dirección normal al plano definido por las dos rectas. Esta proyección nos da la longitud del segmento más corto entre $l_1$ y $l_2$, que es perpendicular a ambas rectas. Este enfoque es particularmente útil en problemas de geometría tridimensional donde las distancias directas no son fácilmente visualizables o medibles.

# %% [markdown]
# ***Ejemplo 03:*** Encontrar la distancia entre las rectas $l_1: \frac{x-4}{2}=\frac{y-5}{4}=\frac{z+4}{3}$ y $l_2: \frac{x+1}{3}=\frac{y-7}{2}=\frac{z-5}{6}$
#
# Para encontrar la distancia entre las rectas $ l_1 $ y $ l_2 $ usaremos la fórmula para la distancia entre dos rectas en el espacio tridimensional:
#
# $$D = \left| \frac{\left( \vec{V_1} \times \vec{V_2} \right) \cdot \vec{P_1P_2}}{|\vec{V_1} \times \vec{V_2}|} \right|$$
#
# donde:
# - $ \vec{V_1} $ y $ \vec{V_2} $ son los vectores dirección de las rectas $ l_1 $ y $ l_2 $, respectivamente.
# - $ \vec{P_1P_2} $ es un vector que conecta un punto conocido $ P_1 $ en la recta $ l_1 $ con un punto conocido $ P_2 $ en la recta $ l_2 $.
#
# Primero, identificaremos los vectores dirección y los puntos en las rectas. Después, aplicaremos la fórmula. Empezaremos extrayendo los vectores dirección y los puntos de las ecuaciones de las rectas.
#
# Los vectores dirección y los puntos en las rectas son:
#
# - Para $ l_1 $: Vector dirección $ \vec{V_1} = (2, 4, 3) $ y punto $ P_1 = (4, 5, -4) $.
# - Para $ l_2 $: Vector dirección $ \vec{V_2} = (3, 2, 6) $ y punto $ P_2 = (-1, 7, 5) $.
# - El vector $ \vec{P_1P_2} $ que conecta $ P_1 $ y $ P_2 $ es $ (-5, 2, 9) $.
#
# Ahora, procederemos a calcular el producto vectorial $ \vec{V_1} \times \vec{V_2} $, su magnitud y finalmente aplicaremos la fórmula de la distancia.
#
#
# $$
# \vec{V_1} \times \vec{V_2} = \begin{vmatrix}
# \hat{i} & \hat{j} & \hat{k} \\
# 2 & 4 & 3 \\
# 3 & 2 & 6
# \end{vmatrix}
# $$
#
# El determinante se calcula expandiendo a lo largo de la primera fila:
#
# $$
# \begin{align*}
# \vec{V_1} \times \vec{V_2} &= \hat{i} \cdot \begin{vmatrix}
# 4 & 3 \\
# 2 & 6
# \end{vmatrix} - \hat{j} \cdot \begin{vmatrix}
# 2 & 3 \\
# 3 & 6
# \end{vmatrix} + \hat{k} \cdot \begin{vmatrix}
# 2 & 4 \\
# 3 & 2
# \end{vmatrix} \\
# &= \hat{i} \cdot (4 \cdot 6 - 3 \cdot 2) - \hat{j} \cdot (2 \cdot 6 - 3 \cdot 3) + \hat{k} \cdot (2 \cdot 2 - 4 \cdot 3) \\
# &= \hat{i} \cdot (24 - 6) - \hat{j} \cdot (12 - 9) + \hat{k} \cdot (4 - 12) \\
# &= \hat{i} \cdot 18 - \hat{j} \cdot 3 + \hat{k} \cdot (-8) \\
# &= (18, -3, -8)
# \end{align*}
# $$
#
# y su magnitud es:
#
# $$|\vec{V_1} \times \vec{V_2}| = \sqrt{18^2 + (-3)^2 + (-8)^2} = \sqrt{324 + 9 + 64} = \sqrt{397} \approx 19.925$$
#
# Ahora realizaremos el cálculo del producto escalar
#
# $$ \left(\vec{V_1} \times \vec{V_2} \right) \cdot \vec{P_1P_2} = 18 \times -5 + (-3) \times 2 + (-8) \times 9 = -90 + (-6) + (-72) = -168$$
#
#
# Reemplazando estos valores en la fórmula para el cálculo de la distancia entre dos rectas en el espacio, se tiene:
#
# $$D = \left| \frac{-168}{19.925} \right| \approx 8.43 \text{ unidades}$$
#
# Con lo que la distancia más corta entre las rectas $l_1: \frac{x-4}{2}=\frac{y-5}{4}=\frac{z+4}{3}$ y $l_2: \frac{x+1}{3}=\frac{y-7}{2}=\frac{z-5}{6}$ es aproximadamente $ 8.43 $ unidades.
#
#
# ***

# %% [markdown]
# ***Ejemplo 04:*** Dados los puntos $P(3,-4,7), Q(15,5,22)$ y $R(7,8,6)$, calcular la distancia entre la recta $l_1$ que pasa por los puntos $R$ y $S$, donde $S$ pertenece al segmento $P Q$ y cumple que $\frac{\overline{P Q}}{\overline{S Q}}=1.5$ y la recta $l_2$ definida por:
#
# $$l_2: \frac{2 x+4}{4}=\frac{-z-2}{-5}=\frac{-3+y}{-1}$$
#
# Para resolver este problema, primero calcularemos la posición del punto $ S $ en el segmento $ PQ $ utilizando la relación dada $ \frac{\overline{PQ}}{\overline{SQ}} = 1.5 $. Luego, encontraremos la ecuación de la recta $ l_1 $ que pasa por los puntos $ R $ y $ S $. Finalmente, calcularemos la distancia entre las rectas $ l_1 $ y $ l_2 $.
#
# - ***Paso 1: Encontrar el punto $ S $ -*** Dado que $ \frac{\overline{PQ}}{\overline{SQ}} = 1.5 $, podemos usar la división de un segmento en una razón dada para encontrar el punto $ S $. La fórmula es:
# $$
# S = \left( \frac{x_1 + rx_2}{1 + r}, \frac{y_1 + ry_2}{1 + r}, \frac{z_1 + rz_2}{1 + r} \right) = \left( \frac{3 + \frac{1}{1.5}15}{1 + \frac{1}{1.5}}, \frac{-4 + \frac{1}{1.5}5}{1 + \frac{1}{1.5}}, \frac{7 + \frac{1}{1.5}22}{1 + \frac{1}{1.5}} \right) \approx \left(7.8, -0.4, 13.0 \right)
# $$
#
#
# - ***Paso 2: Ecuación de la recta $ l_1 $ -*** Una vez que tengamos el punto $ S $, podremos hallar la ecuación de la recta $ l_1 $ que pasa por $ R $ y $ S $. La fórmula general para la ecuación de una recta en 3D que pasa por dos puntos $ A $ y $ B $ es:
# $$
# \frac{x - x_A}{x_B - x_A} = \frac{y - y_A}{y_B - y_A} = \frac{z - z_A}{z_B - z_A}.
# $$
#
# Sustituyendo las coordenadas de $ R $ y $ S $:
#
# $$l_1: \frac{x - 7}{7.8 - 7} = \frac{y - 8}{-0.4 - 8} = \frac{z - 6}{13 - 6}$$
# $$l_1: \frac{x - 7}{0.8} = \frac{y - 8}{-8.4} = \frac{z - 6}{7}$$
#
# - ***Paso 3: Ecuación de la recta $ l_2 $ -*** La ecuación de la recta $ l_2 $ ya está dada:
# $$
# l_2: \frac{2x+4}{4} = \frac{-z-2}{-5} = \frac{-3+y}{-1}.
# $$
#
# - ***Paso 4: Calcular la distancia entre $ l_1 $ y $ l_2 $ -*** Finalmente, usaremos la fórmula para calcular la distancia entre dos rectas en el espacio, que ya hemos utilizado en ejemplos anteriores.
#
# La distancia entre las rectas $ l_1 $ y $ l_2 $ se calcula usando la fórmula que hemos discutido anteriormente. Primero, necesitamos identificar un punto y el vector dirección para cada recta. Para $ l_2 $, podemos deducir el vector dirección de la ecuación dada y elegir un punto en la recta. Ya tenemos la ecuación de $ l_1 $ y un punto sobre ella.
#
# Procedamos a calcular estos elementos y luego usemos la fórmula para calcular la distancia.
#
# Los elementos necesarios para calcular la distancia entre las rectas son:
#
# - Vector dirección de $ l_1 $, $ \vec{V_1} $: $ (0.8, -8.4, 7) $.
# - Vector dirección de $ l_2 $, $ \vec{V_2} $: $ (4, -1, -5) $.
# - Vector que conecta un punto en $ l_1 $ (usamos $ R $) y un punto en $ l_2 $ (elegido para $ t = 0 $ en la ecuación de $ l_2 $): $ (-9, -5, -8) $.
#
# Ahora calcularemos la distancia entre las rectas $ l_1 $ y $ l_2 $ utilizando la fórmula:
# $$
# D = \left| \frac{(\vec{V_1} \times \vec{V_2}) \cdot \vec{RP_{l2}}}{|\vec{V_1} \times \vec{V_2}|} \right|.
# $$
#
# Primero, encontraremos $ \vec{V_1} \times \vec{V_2} $, su magnitud, y luego calcularemos el producto escalar con $ \vec{RP_{l2}} $ para obtener la distancia. Procedamos con estos cálculos.
#
# - Producto vectorial $ \vec{V_1} \times \vec{V_2} $: $ (49, 32, 32.8) $.
# - Magnitud de $ \vec{V_1} \times \vec{V_2} $: $ 67.0883 $.
# - Producto escalar de $ (\vec{V_1} \times \vec{V_2}) $ y $ \vec{RP_{l2}} $: $ -863.4 $.
#
# La distancia $ D $ entre las rectas es aproximadamente $ 12.87 $ unidades.
#
# ***

# %% [markdown]
# - ***Ejemplo 05:*** Determinar la posición relativa de las rectas:
# $$
# \begin{aligned}
# & l_1:\left\{\begin{array}{l}
# x=2+4 t \\
# y=3 \\
# z=1-t
# \end{array}\right. \\
# & y=\left\{\begin{array}{l}
# x=2+4 t \\
# y=3+2 t \\
# z=1+t
# \end{array}\right.
# \end{aligned}
# $$
#
#
# - ***Comparación de Vectores Dirección:*** Para cada recta, el vector dirección se determina por los coeficientes de $ t $ en las ecuaciones paramétricas.
#
# - **Recta $ l_1 $**: El vector dirección es $ \vec{V_1} = (4, 0, -1)$.
# - **Recta $ l_2 $**: El vector dirección es $ \vec{V_2} = (4, 2, 1) $.
#
# Comparando estos vectores, podemos observar que los vectores dirección no son proporcionales, ya que no existe un escalar constante que pueda multiplicar cada componente de $ \vec{V_1} $ para obtener las componentes correspondientes de $ \vec{V_2} $.
#
# - ***Verificación de Puntos Comunes:*** Las rectas tienen un punto común si existe un valor de $ t $ que satisfaga todas las ecuaciones de ambas rectas simultáneamente. Comparando las ecuaciones de $ x $ y $ z $, vemos que podrían tener puntos en común. Sin embargo, las ecuaciones para $ y $ son diferentes:
#
# - Para $ l_1 $, $ y = 3 $.
# - Para $ l_2 $, $ y = 3 + 2t $.
#
# Para los mismos valores de $ t $, no hay un valor de $ y $ que satisfaga ambas ecuaciones. Por lo tanto, no existe un punto común entre $ l_1 $ y $ l_2 $.
#
# - ***Conclusión:*** Dado que los vectores dirección no son proporcionales y no existe un punto común para las dos rectas, concluimos que $ l_1 $ y $ l_2 $ son **rectas cruzadas** o **secantes no coplanares**. Esto significa que no se intersecan ni son paralelas en el espacio tridimensional.
#
# ***

# %% [markdown]
# - ***Ejemplo 06:*** Hallar la(s) ecuación(es) de la(s) recta(s) que pasan por el punto $(3,-3,4)$ y es(son) perpendicular(es) a las rectas $l_1: \frac{2 x+4}{4}=\frac{-3+y}{-1}=\frac{-z-2}{-5}$ y $l_2: x-3=\frac{2 y-7}{2}=\frac{3-z}{-3}$.
#
# Para hallar la(s) ecuación(es) de la(s) recta(s) que pasan por el punto $ (3, -3, 4) $ y son perpendiculares a las rectas $ l_1 $ y $ l_2 $, seguimos los siguientes pasos:
#
# - ***Determinar los Vectores Dirección de $ l_1 $ y $ l_2 $:*** Las ecuaciones de las rectas son:
#
# $$
# l_1: \frac{2x+4}{4} = \frac{-3+y}{-1} = \frac{-z-2}{-5}
# $$
#
# y
#
# $$
# l_2: x-3 = \frac{2y-7}{2} = \frac{3-z}{-3}.
# $$
#
# De estas ecuaciones, podemos deducir los vectores dirección:
#
# - Para $ l_1 $: $ \vec{V_1} = (4, -1, -5) $ (coeficientes de $ x $, $ y $, $ z $ respectivamente).
# - Para $ l_2 $: $ \vec{V_2} = (1, 2, -3) $ (coeficientes de $ x $, $ y $, $ z $ respectivamente).
#
# ***Encontrar un Vector Perpendicular a Ambos $ \vec{V_1} $ y $ \vec{V_2} $:*** Necesitamos encontrar un vector $ \vec{N} $ que sea perpendicular a ambos $ \vec{V_1} $ y $ \vec{V_2} $. Esto se puede hacer encontrando el producto vectorial de $ \vec{V_1} $ y $ \vec{V_2} $:
#
# $$
# \vec{N} = \vec{V_1} \times \vec{V_2}.
# $$
#
# Calcularemos este producto vectorial:
#
# - ***Paso 3: Formar la Ecuación de la Recta:*** Una vez que tengamos $ \vec{N} $, la ecuación de la recta que pasa por $ (3, -3, 4) $ y es perpendicular a $ l_1 $ y $ l_2 $ se puede formar usando la ecuación paramétrica de una recta:
#
# $$
# \begin{cases}
# x = x_0 + at \\
# y = y_0 + bt \\
# z = z_0 + ct
# \end{cases}
# $$
#
# donde $ (x_0, y_0, z_0) $ es el punto por el que pasa la recta (en este caso, $ (3, -3, 4) $) y $ (a, b, c) $ son las componentes del vector $ \vec{N} $.
#
# Realicemos estos cálculos.
#
# El vector $ \vec{N} $, que es perpendicular a ambos vectores dirección $ \vec{V_1} $ y $ \vec{V_2} $, tiene componentes $ (13, 7, 9) $.
#
# - ***Paso 3: Formar la Ecuación de la Recta:*** Con el punto dado $ (3, -3, 4) $ y el vector $ \vec{N} = (13, 7, 9) $, la ecuación de la recta que buscamos es:
#
# $$
# \begin{cases}
# x = 3 + 13t \\
# y = -3 + 7t \\
# z = 4 + 9t
# \end{cases}
# $$
#
# donde $ t $ es el parámetro. Esta es la ecuación de la recta que pasa por el punto $ (3, -3, 4) $ y es perpendicular a las rectas $ l_1 $ y $ l_2 $.
#
# ***

# %% [markdown]
# - ***Ejemplo 07:*** Dados el vector $\overrightarrow{N}=[4 \mathrm{i}-4 \mathrm{j}-2 \mathrm{k}]$ y el punto $T(-4,-2,5)$. Determine la forma paramétrica y simétrica de la recta que es perpendicular a $\overrightarrow{N}$ y que para por el punto $T$.
#
# Para encontrar la forma paramétrica y simétrica de la recta que es perpendicular al vector $ \overrightarrow{N} $ y pasa por el punto $ T(-4, -2, 5) $, seguimos estos pasos:
#
# 1. Obtener un vector dirección para la recta perpendicular a $ \overrightarrow{N} $. Esto puede lograrse tomando el vector $ \overrightarrow{N} $ y encontrando un vector perpendicular a él, lo cual se puede hacer tomando el producto cruz entre $ \overrightarrow{N} $ y cualquier otro vector no paralelo a él.
# 2. Usar el punto dado $ T $ y el vector dirección encontrado para escribir la ecuación paramétrica de la recta.
# 3. Luego, convertir esta ecuación paramétrica en su forma simétrica.
#
# ***Paso 1: Obtener un Vector Dirección Perpendicular***
#
# Dado que $ \overrightarrow{N} = [4 \mathbf{i} - 4 \mathbf{j} - 2 \mathbf{k}] $, podemos tomar el producto cruz entre $ \overrightarrow{N} $ y algún otro vector no paralelo a él para obtener un vector perpendicular.
#
# Tomamos el vector $ \vec{v} = [1 \mathbf{i} + 1 \mathbf{j} + 1 \mathbf{k}] $ y calculamos el producto cruz entre $ \overrightarrow{N} $ y $ \vec{v} $:
#
# $$
# \overrightarrow{N} \times \vec{v} =
# \begin{vmatrix}
# \mathbf{i} & \mathbf{j} & \mathbf{k} \\
# 4 & -4 & -2 \\
# 1 & 1 & 1 \\
# \end{vmatrix}
# $$
#
# $$
# = \mathbf{i} \begin{vmatrix} -4 & -2 \\ 1 & 1 \end{vmatrix} - \mathbf{j} \begin{vmatrix} 4 & -2 \\ 1 & 1 \end{vmatrix} + \mathbf{k} \begin{vmatrix} 4 & -4 \\ 1 & 1 \end{vmatrix}
# $$
#
# $$
# = \mathbf{i}(-4 - (-2)) - \mathbf{j}(4 - (-2)) + \mathbf{k}(4 - (-4)) = \mathbf{i}(-4 + 2) - \mathbf{j}(4 + 2) + \mathbf{k}(4 + 4) = \mathbf{i}(-2) - \mathbf{j}(6) + \mathbf{k}(8)
# $$
#
# Entonces, el vector dirección perpendicular es $ \overrightarrow{v} = [-2 \mathbf{i} - 6 \mathbf{j} + 8 \mathbf{k}] $.
#
#
# ***Paso 2: Escribir la Ecuación Paramétrica de la Recta***
#
# Usamos el punto dado $ T(-4, -2, 5) $ y el vector dirección perpendicular encontrado para escribir la ecuación paramétrica de la recta.
#
# La ecuación paramétrica de la recta es:
#
# $$
# \begin{cases}
# x &= -4 - 2t \\
# y &= -2 - 6t \\
# z &= 5 + 8t
# \end{cases}
# $$
#
# ***Paso 3: Convertir a la Forma Simétrica***
#
# La forma simétrica de la recta es:
#
# $$
# \frac{x + 4}{-2} = \frac{y + 2}{-6} = \frac{z - 5}{8}
# $$
#
# Esta es la ecuación de la recta que es perpendicular a $ \overrightarrow{N} $ y pasa por el punto $ T(-4, -2, 5) $.

# %% [markdown]
# - ***Ejemplo 08:*** Dos de los ángulos directores de una recta son $\cos 45^{\circ}, \cos 60^{\circ}$. Si la recta pasa por el punto $P(4,-1,4)$, hállese sus ecuaciones (dos soluciones).
#
# Para encontrar las ecuaciones de la recta dadas dos de sus ángulos directores y que pase por el punto $ P(4, -1, 4) $, seguimos estos pasos:
#
# ***Paso 1.*** Convertir los ángulos directores dados en vectores de dirección $ \vec{V} $.
#
# Dado que los ángulos directores son $ \cos 45^\circ $ y $ \cos 60^\circ $, podemos usar trigonometría para encontrar las componentes del vector de dirección $ \vec{V} $.
#
# Para un ángulo $ \theta $ con respecto al eje $ x $, las componentes del vector de dirección son $ (\cos \theta, \sin \theta, 0) $. Dado que solo conocemos los ángulos directores, asumiremos que uno de ellos es el ángulo con el eje $ x $ y el otro es el ángulo con el eje $ y $ (el eje $ z $ es irrelevante ya que no se especifica). Luego, tomamos $ \theta = 45^\circ $ y $ \phi = 60^\circ $.
#
# Por lo tanto, los vectores de dirección son $ \vec{V_1} = (\cos 45^\circ, \sin 45^\circ, 0) $ y $ \vec{V_2} = (\cos 60^\circ, \sin 60^\circ, 0) $.
#
# Dado que $ \cos 45^\circ = \frac{1}{\sqrt{2}} $ y $ \cos 60^\circ = \frac{1}{2} $, los vectores de dirección son:
#
# $$
# \vec{V_1} = \left(\frac{1}{\sqrt{2}}, \frac{1}{\sqrt{2}}, 0\right)
# $$
# $$
# \vec{V_2} = \left(\frac{1}{2}, \frac{\sqrt{3}}{2}, 0\right)
# $$
#
#
# ***Paso 2.*** Utilizar el punto dado $ P(4, -1, 4) $ y los vectores de dirección $ \vec{V} $ para escribir las ecuaciones paramétricas de la recta.
#
# Usamos el punto dado $ P(4, -1, 4) $ y los vectores de dirección $ \vec{V_1} $ y $ \vec{V_2} $ para escribir las ecuaciones paramétricas de la recta.
#
# Las ecuaciones paramétricas de la recta son:
#
# $$
# \begin{cases}
# x &= 4 + \frac{1}{\sqrt{2}}t \\
# y &= -1 + \frac{1}{\sqrt{2}}t \\
# z &= 4
# \end{cases}
# $$
#
# y
#
# $$
# \begin{cases}
# x &= 4 + \frac{1}{2}t \\
# y &= -1 + \frac{\sqrt{3}}{2}t \\
# z &= 4
# \end{cases}
# $$
#
# ***Paso 3.*** Convertir las ecuaciones paramétricas a su forma simétrica.
#
# Convertimos las ecuaciones paramétricas de la recta a su forma simétrica.
#
# Para la primera solución:
#
# $$
# \frac{x - 4}{\frac{1}{\sqrt{2}}} = \frac{y + 1}{\frac{1}{\sqrt{2}}} = \frac{z - 4}{0}
# $$
#
# y
#
# $$
# \frac{x - 4}{\frac{1}{2}} = \frac{y + 1}{\frac{\sqrt{3}}{2}} = \frac{z - 4}{0}
# $$
#
# Para la segunda solución, obtenemos la misma forma simétrica pero con los valores correspondientes de $ \vec{V_2} $.
#
# ***

# %% [markdown]
# - ***Ejemplo 09:*** Demostrar que los puntos $A(3,4,2), B(-1,5,3)$ y $C(2,1,4)$ no son colineales. Luego hallar la ecuación de la línea perpendicular a dicho plano y que pasa por el origen.
#
# Para demostrar que los puntos $ A(3,4,2) $, $ B(-1,5,3) $ y $ C(2,1,4) $ no son colineales, podemos verificar si el vector formado por dos de los puntos es linealmente independiente del vector formado por los otros dos puntos. Luego, para encontrar la ecuación de la línea perpendicular al plano formado por estos puntos y que pasa por el origen, podemos usar el producto cruz.
#
# ***Paso 1 - Verificar Colinealidad:*** Verificaremos si los vectores $ \overrightarrow{AB} $ y $ \overrightarrow{AC} $ son linealmente independientes. Si lo son, entonces los puntos no son colineales.
#
# Calculamos los vectores dirección $ \overrightarrow{AB} $ y $ \overrightarrow{AC} $:
#
# $$\overrightarrow{AB} = B - A = (-1 - 3, 5 - 4, 3 - 2) = (-4, 1, 1)$$
# $$\overrightarrow{AC} = C - A = (2 - 3, 1 - 4, 4 - 2) = (-1, -3, 2)$$
#
# Los vectores no son proporcionales, lo que indica que los puntos no son colineales.
#
# ***Paso 2 - Encontrar la Ec. del Plano y la Línea Perpendicular:*** Una vez que confirmemos que los puntos no son colineales, podemos usar el producto cruz entre los vectores $ \overrightarrow{AB} $ y $ \overrightarrow{AC} $ para encontrar un vector normal al plano que pasará por el origen. Luego, usaremos este vector normal para escribir la ecuación de la línea perpendicular que pasa por el origen.
#
# Usamos el producto cruz entre $ \overrightarrow{AB} $ y $ \overrightarrow{AC} $ para encontrar un vector normal al plano:
#
# $$\overrightarrow{n} = \overrightarrow{AB} \times \overrightarrow{AC} = \begin{vmatrix} \mathbf{i} & \mathbf{j} & \mathbf{k} \\ -4 & 1 & 1 \\ -1 & -3 & 2 \end{vmatrix} = \mathbf{i} \begin{vmatrix} 1 & 1 \\ -3 & 2 \end{vmatrix} - \mathbf{j} \begin{vmatrix} -4 & 1 \\ -1 & 2 \end{vmatrix} + \mathbf{k} \begin{vmatrix} -4 & 1 \\ -1 & -3 \end{vmatrix}$$
#
# $$= \mathbf{i}((1)(2) - (1)(-3)) - \mathbf{j}((-4)(2) - (1)(-1)) + \mathbf{k}((-4)(-3) - (1)(-1)) = \mathbf{i}(2 + 3) - \mathbf{j}(-8 + 1) + \mathbf{k}(12 + 1) = \mathbf{i}5 - \mathbf{j}-7 + \mathbf{k}13$$
#
# Por lo tanto, el vector normal al plano es $ \overrightarrow{n} = (5, -7, 13) $.
#
# Entonces, la ecuación del plano que pasa por los puntos $ A $, $ B $ y $ C $ es:
#
# $$5x - 7y + 13z + D = 0$$
#
# Para encontrar $ D $, podemos usar cualquiera de los puntos. Usaremos $ A(3, 4, 2) $:
#
# $$5(3) - 7(4) + 13(2) + D = 0$$
#
# $$15 - 28 + 26 + D = 0$$
#
# $$13 - 28 + D = 0$$
#
# $$-15 + D = 0$$
#
# $$D = 15$$
#
# Por lo tanto, la ecuación del plano es:
#
# $$5x - 7y + 13z + 15 = 0$$
#
# Finalmente, la ecuación de la línea perpendicular que pasa por el origen es simplemente el vector normal al plano, es decir:
#
# $$\frac{x}{5} = \frac{y}{-7} = \frac{z}{13}$$
# ***

# %% [markdown]
# - ***Ejemplo 10:*** Para las lineas $l_1: \frac{x+2}{3}=y+3=\frac{z-1}{2} y$
# $l_2: 2 x-1=-4 y-7=-z+4$, determinar:
# 1. Si se cruzan o se cortan.
# 2. En caso de cortarse determinar si se trata de la misma recta o si son distintas en este último caso obtener el punto donde se cortan.
#
# Para determinar si las líneas $ l_1 $ y $ l_2 $ se cruzan o se cortan, primero necesitamos expresar ambas líneas en forma paramétrica. Luego, podemos igualar las ecuaciones paramétricas para ver si tienen solución. Si tienen solución, las líneas se cruzan. Si no tienen solución, las líneas son paralelas o coincidentes.
#
# ***Expresión Paramétrica de las Líneas***
#
# Para $ l_1 $:
# $$ \frac{x+2}{3}=y+3=\frac{z-1}{2} \quad \Rightarrow \quad x = 3t - 2, \ y = t - 3, \ z = 2t + 1$$
#
# Para $ l_2 $:
# $$2x - 1 = -4y - 7 = -z + 4 \quad \Rightarrow \quad x = \frac{1}{2}, \ y = -\frac{1}{4} t - \frac{9}{4}, \ z = -t + 4$$
#
# ***Paso 1. Determinar si se Cruzan o se Cortan:*** Para que las líneas se crucen, deben tener una solución común en forma de un punto. Esto sucede cuando las ecuaciones paramétricas tienen una solución única. Igualaremos las ecuaciones paramétricas de $ l_1 $ y $ l_2 $ para encontrar $ t $.
#
# Igualamos $ x $ y $ z $ de las ecuaciones paramétricas de $ l_1 $ y $ l_2 $:
#
# $$3t - 2 = \frac{1}{2} \quad \text{y} \quad 2t + 1 = -t + 4$$
#
# Resolviendo para $ t $:
#
# $$3t = \frac{5}{2} \quad \Rightarrow \quad t = \frac{5}{6}$$
#
# Sustituyendo $ t = \frac{5}{6} $ en las ecuaciones paramétricas, encontramos las coordenadas del punto donde las líneas se cruzan.
#
# ***Paso 2. En caso de Cortarse:*** Ahora que sabemos que las líneas se cortan, verificamos si son la misma línea o diferentes. Para hacerlo, comparamos sus ecuaciones paramétricas. Si son iguales, son la misma línea; si son diferentes, son distintas.
#
# Para $ l_1 $:
# $$x = 3 \left(\frac{5}{6}\right) - 2 = \frac{1}{2}, \quad y = \frac{5}{6} - 3 = -\frac{13}{6}, \quad z = 2 \left(\frac{5}{6}\right) + 1 = \frac{17}{3}$$
#
# Para $ l_2 $:
# $$x = \frac{1}{2}, \quad y = -\frac{1}{4} \left(\frac{5}{6}\right) - \frac{9}{4} = -\frac{13}{6}, \quad z = -\frac{5}{6} + 4 = \frac{17}{3}$$
#
# Como las coordenadas son iguales, las líneas no son distintas y se cortan en el punto $(\frac{1}{2}, -\frac{13}{6}, \frac{17}{3})$.
